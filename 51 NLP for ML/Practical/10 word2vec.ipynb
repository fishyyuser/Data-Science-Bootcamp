# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in d:\projects\data-science-bootcamp\venv\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in d:\projects\data-science-bootcamp\venv\lib\site-packages (from gensim) (2.2.6)
# Requirement already satisfied: scipy>=1.7.0 in d:\projects\data-science-bootcamp\venv\lib\site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in d:\projects\data-science-bootcamp\venv\lib\site-packages (from gensim) (7.4.2)
# Requirement already satisfied: wrapt in d:\projects\data-science-bootcamp\venv\lib\site-packages (from smart_open>=1.8.1->gensim) (2.0.0)

# %%
import gensim

# %%
from gensim.models import Word2Vec,KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']

# %%
len(vec_king)
# Out:
# 300

# %%
wv.most_similar(vec_king)
# Out:
# [('king', 1.0),
#  ('kings', 0.7138044834136963),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864824056625366),
#  ('ruler', 0.5797566771507263),
#  ('princes', 0.5646551847457886),
#  ('Prince_Paras', 0.543294370174408)]

# %%
vec=wv['boy']+wv['queen']-wv['girl']

# %%
wv.most_similar([vec])
# Out:
# [('queen', 0.8684327006340027),
#  ('king', 0.730460524559021),
#  ('queens', 0.6272136569023132),
#  ('monarch', 0.6115334630012512),
#  ('kings', 0.6099238395690918),
#  ('princess', 0.5679125189781189),
#  ('royal', 0.561561644077301),
#  ('prince', 0.556454062461853),
#  ('NYC_anglophiles_aflutter', 0.5429462790489197),
#  ('Queen', 0.5397148728370667)]

# %%
wv.similarity("king","queen")
# Out:
# np.float32(0.6510957)

# %%
test_vec=wv['monarch']+wv['Man']
wv.most_similar([test_vec])
# Out:
# [('monarch', 0.7397297620773315),
#  ('Man', 0.6743344068527222),
#  ('king', 0.568002462387085),
#  ('prince', 0.5535213351249695),
#  ('crown_prince', 0.5401299595832825),
#  ('monarchy', 0.5363500714302063),
#  ('royal', 0.5127941966056824),
#  ('expert_Dickie_Arbiter', 0.5112439393997192),
#  ('royal_consort', 0.5082696080207825),
#  ('queen', 0.5077536702156067)]
