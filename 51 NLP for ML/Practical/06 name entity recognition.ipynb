# %%
"""
Person Eg: Pradyumn Bisht
Place Or Location Eg: India
Date Eg: September,24-09-1989
Time  Eg: 4:30pm
Money Eg: 1 million dollar
Organization Eg: iNeuron Private Limited
Percent Eg: 20%, twenty percent
"""
# Out:
# '\nPerson Eg: Pradyumn Bisht\nPlace Or Location Eg: India\nDate Eg: September,24-09-1989\nTime  Eg: 4:30pm\nMoney Eg: 1 million dollar\nOrganization Eg: iNeuron Private Limited\nPercent Eg: 20%, twenty percent\n'

# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
from nltk.tokenize import word_tokenize
words=word_tokenize(sentence)

# %%
from nltk.tag import pos_tag
tag_elements=pos_tag(words,lang="eng")
print(tag_elements)
# Out:
# [('The', 'DT'), ('Eiffel', 'NNP'), ('Tower', 'NNP'), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), ('French', 'JJ'), ('engineer', 'NN'), ('Gustave', 'NNP'), ('Eiffel', 'NNP'), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')]

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to d:\Projects\Data-Science-
# [nltk_data]     Bootcamp\venv\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
from nltk.chunk import ne_chunk
chunked=ne_chunk(tag_elements).draw()
