# %%
import pandas as pd
import numpy as np
messages=pd.read_csv('smsspamcollection/SMSSpamCollection',
                    sep='\t',names=["label","message"])
print(messages.shape)
messages.head()
# Out:
# (5572, 2)
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## data cleaninig and pre-processing
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
sbs=SnowballStemmer('english')
stopwords_eng=stopwords.words('english')

# %%
from nltk.tokenize import word_tokenize
import re
def process_text(msg):
    msg=msg.lower()
    msg = re.sub(r'[^a-z0-9\s]', '', msg)
    words=word_tokenize(msg)
    words=[sbs.stem(word) for word in words if word not in stopwords_eng]
    return " ".join(words)

# %%
### using lemmatization instead of stemming
from nltk.stem import WordNetLemmatizer as wnl
wnl=wnl()
def process_text_lemmatization(msg):
    msg=msg.lower()
    msg = re.sub(r'[^a-z0-9\s]', '', msg)
    words=word_tokenize(msg)
    words=[wnl.lemmatize(word) for word in words if word not in stopwords_eng]
    return " ".join(words)

# %%
corpus=[]
for msg in messages['message']:
    sent=process_text(msg)
    corpus.append(sent)

# %%
corpus
# Out:
# ['go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#  'ok lar joke wif u oni',
#  'free entri 2 wkli comp win fa cup final tkts 21st may 2005 text fa 87121 receiv entri questionstd txt ratetc appli 08452810075over18',
#  'u dun say earli hor u c alreadi say',
#  'nah dont think goe usf live around though',
#  'freemsg hey darl 3 week word back id like fun still tb ok xxx std chgs send 150 rcv',
#  'even brother like speak treat like aid patent',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press 9 copi friend callertun',
#  'winner valu network custom select receivea 900 prize reward claim call 09061701461 claim code kl341 valid 12 hour',
#  'mobil 11 month u r entitl updat latest colour mobil camera free call mobil updat co free 08002986030',
#  'im gon na home soon dont want talk stuff anymor tonight k ive cri enough today',
#  'six chanc win cash 100 20000 pound txt csh11 send 87575 cost 150pday 6day 16 tsandc appli repli hl 4 info',
#  'urgent 1 week free membership 100000 prize jackpot txt word claim 81010 tc wwwdbuknet lccltd pobox 4403ldnw1a7rw18',
#  'ive search right word thank breather promis wont take help grant fulfil promis wonder bless time',
#  'date sunday',
#  'xxxmobilemovieclub use credit click wap link next txt messag click httpwap xxxmobilemovieclubcomnqjkgighjjgcbl',
#  'oh kim watch',
#  'eh u rememb 2 spell name yes v naughti make v wet',
#  'fine that way u feel that way gota b',
#  'england v macedonia dont miss goalsteam news txt ur nation team 87077 eg england 87077 trywal scotland 4txt120 poboxox36504w45wq 16',
#  'serious spell name',
#  'im go tri 2 month ha ha joke',
#  'pay first lar da stock comin',
#  'aft finish lunch go str lor ard 3 smth lor u finish ur lunch alreadi',
#  'ffffffffff alright way meet sooner',
#  'forc eat slice im realli hungri tho suck mark get worri know im sick turn pizza lol',
#  'lol alway convinc',
#  'catch bus fri egg make tea eat mom left dinner feel love',
#  'im back amp pack car ill let know there room',
#  'ahhh work vagu rememb feel like lol',
#  'wait that still clear sure sarcast that x doesnt want live us',
#  'yeah got 2 v apologet n fallen actin like spoilt child got caught till 2 wont go bad cheer',
#  'k tell anyth',
#  'fear faint housework quick cuppa',
#  'thank subscript rington uk mobil charg 5month pleas confirm repli yes repli charg',
#  'yup ok go home look time msg xuhui go learn 2nd may lesson 8am',
#  'oop ill let know roommat done',
#  'see letter b car',
#  'anyth lor u decid',
#  'hello how saturday go text see youd decid anyth tomo im tri invit anyth',
#  'pls go ahead watt want sure great weekend abiola',
#  'forget tell want need crave love sweet arabian steed mmmmmm yummi',
#  '07732584351 rodger burn msg tri call repli sms free nokia mobil free camcord pleas call 08000930705 deliveri tomorrow',
#  'see',
#  'great hope like man well endow ltgt inch',
#  'callsmessagesmiss call',
#  'didnt get hep b immunis nigeria',
#  'fair enough anyth go',
#  'yeah hope tyler cant could mayb ask around bit',
#  'u dont know stubborn didnt even want go hospit kept tell mark im weak sucker hospit weak sucker',
#  'think first time saw class',
#  'gram usual run like ltgt half eighth smarter though get almost whole second gram ltgt',
#  'k fyi x ride earli tomorrow morn hes crash place tonight',
#  'wow never realiz embarass accomod thought like sinc best could alway seem happi cave im sorri didnt dont give im sorri offer im sorri room embarass',
#  'sms ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end repli end sptv',
#  'know mallika sherawat yesterday find lturlgt',
#  'congrat 1 year special cinema pass 2 call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420ip45w 150pm dont miss',
#  'sorri ill call later meet',
#  'tell reach',
#  'yesgauti sehwag odi seri',
#  'gon na pick 1 burger way home cant even move pain kill',
#  'ha ha ha good joke girl situat seeker',
#  'part check iq',
#  'sorri roommat took forev ok come',
#  'ok lar doubl check wif da hair dresser alreadi said wun cut v short said cut look nice',
#  'valu custom pleas advis follow recent review mob award 1500 bonus prize call 09066364589',
#  'today song dedic day song u dedic send ur valuabl frnds first rpli',
#  'urgent ur award complimentari trip eurodisinc trav acoentry41 1000 claim txt dis 87121 186150morefrmmob shracomorsglsuplt10 ls1 3aj',
#  'hear new divorc barbi come ken stuff',
#  'plane give month end',
#  'wah lucki man save money hee',
#  'finish class',
#  'hi babe im home wan na someth xx',
#  'kkwhere youhow perform',
#  'u call',
#  'wait machan call free',
#  'that cool gentleman treat digniti respect',
#  'like peopl much shi pa',
#  'oper ltgt',
#  'still look job much tas earn',
#  'sorri ill call later',
#  'k call ah',
#  'ok way home hi hi',
#  'place man',
#  'yup next stop',
#  'call later dont network urgnt sms',
#  'real u get yo need 2 ticket one jacket im done alreadi use multi',
#  'yes start send request make pain came back im back bed doubl coin factori got ta cash nitro',
#  'im realli still tonight babe',
#  'ela kanoil download come wen ur free',
#  'yeah dont stand close tho youll catch someth',
#  'sorri pain ok meet anoth night spent late afternoon casualti mean havent done stuff42moro includ time sheet sorri',
#  'smile pleasur smile pain smile troubl pour like rain smile sum1 hurt u smile becoz someon still love see u smile',
#  'pleas call custom servic repres 0800 169 6031 10am9pm guarante 1000 cash 5000 prize',
#  'havent plan buy later check alreadi lido got 530 show e afternoon u finish work alreadi',
#  'free rington wait collect simpli text password mix 85069 verifi get usher britney fml po box 5249 mk17 92h 450ppw 16',
#  'watch telugu moviewat abt u',
#  'see finish load loan pay',
#  'hi wk ok hol yes bit run forgot hairdress appoint four need get home n shower beforehand caus prob u',
#  'see cup coffe anim',
#  'pleas dont text anymor noth els say',
#  'okay name ur price long legal wen pick u ave x am xx',
#  'im still look car buy gone 4the drive test yet',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press 9 copi friend callertun',
#  'wow your right didnt mean guess gave boston men chang search locat nyc someth chang cuz signin page still say boston',
#  'umma life vava umma love lot dear',
#  'thank lot wish birthday thank make birthday truli memor',
#  'aight ill hit get cash',
#  'would ip address test consid comput isnt minecraft server',
#  'know grumpi old peopl mom like better lie alway one play joke',
#  'dont worri guess hes busi',
#  'plural noun research',
#  'go dinnermsg',
#  'im ok wif cos like 2 tri new thing scare u dun like mah cos u said loud',
#  'gent tri contact last weekend draw show 1000 prize guarante call 09064012160 claim code k52 valid 12hrs 150ppm',
#  'wa ur openin sentenc formal anyway im fine juz tt im eatin much n puttin weighthaha anythin special happen',
#  'enter cabin pa said happi bday boss felt special askd 4 lunch lunch invit apart went',
#  'winner u special select 2 receiv 1000 4 holiday flight inc speak live oper 2 claim 0871277810910pmin 18',
#  'goodo yes must speak friday eggpotato ratio tortilla need',
#  'hmmmi uncl inform hes pay school direct pls buy food',
#  'privat 2004 account statement 07742676969 show 786 unredeem bonus point claim call 08719180248 identifi code 45239 expir',
#  'urgent mobil award 2000 bonus caller prize 5903 final tri contact u call landlin 09064019788 box42wr29c 150ppm',
#  'new address applespairsal malarki',
#  'today voda number end 7548 select receiv 350 award match pleas call 08712300220 quot claim code 4041 standard rate app',
#  'go sao mu today done 12',
#  'predict wat time finish buy',
#  'good stuff',
#  'knowyetund hasnt sent money yet sent text bother send dont involv anyth shouldnt impos anyth first place apologis',
#  'room',
#  'hey girl r u hope u r well del r bak long time c give call sum time lucyxx',
#  'kkhow much cost',
#  'im home',
#  'dear call tmorrowpl accomod',
#  'first answer question',
#  'sunshin quiz wkli q win top soni dvd player u know countri algarv txt ansr 82277 150 sptyron',
#  'want 2 get laid tonight want real dog locat sent direct 2 ur mob join uk largest dog network bt txting gravel 69888 nt ec2a 31pmsg150p',
#  'haf msn yijuehotmailcom',
#  'call meet',
#  'check room befor activ',
#  'youll rcv msgs chat svc free hardcor servic text go 69988 u get noth u must age verifi yr network tri',
#  'got c lazi type forgot lect saw pouch like v nice',
#  'k text your way',
#  'sir wait mail',
#  'swt thought nver get tire littl thing 4 lovabl person cozsomtim littl thing occupi biggest part heart gud ni8',
#  'know pls open back',
#  'yes see ya dot',
#  'what staff name take class us',
#  'freemsg havent repli text im randi sexi femal live local luv hear u netcollex ltd 08700621170150p per msg repli stop end',
#  'ummmawil call check inour life begin qatar pls pray hard',
#  'ki delet contact',
#  'sindu got job birla soft',
#  'wine flow im never',
#  'yup thk cine better cos need 2 go 2 plaza mah',
#  'ok ur typic repli',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press 9 copi friend callertun',
#  'everywher dirt floor window even shirt sometim open mouth come flow dream world without half chore time joy lot tv show ill see guess like thing must exist like rain hail mist time done becom one',
#  'aaooooright work',
#  'im leav hous',
#  'hello love get interview today happi good boy think mear miss',
#  'custom servic annonc new year deliveri wait pleas call 07046744435 arrang deliveri',
#  'winner u special select 2 receiv 1000 cash 4 holiday flight inc speak live oper 2 claim 0871277810810',
#  'keep safe need miss alreadi envi everyon see real life',
#  'new car hous parentsi new job hand',
#  'im love im excit day spend make happi',
#  'pls stop bootydeli 32f invit friend repli yes434 no434 see wwwsmsacubootydeli stop send stop frnd 62468',
#  'bangbab ur order way u receiv servic msg 2 download ur content u goto wap bangb tv ur mobil internetservic menu',
#  'place ur point e cultur modul alreadi',
#  'urgent tri contact last weekend draw show 900 prize guarante call 09061701939 claim code s89 valid 12hrs',
#  'hi frnd best way avoid missunderstd wit belov one',
#  'great escap fanci bridg need lager see tomo',
#  'yes complet formclark also utter wast',
#  'sir need axi bank account bank address',
#  'hmmm thk sure got time hop ard ya go 4 free abt muz call u discuss liao',
#  'time come later',
#  'bloodi hell cant believ forgot surnam mr ill give u clue spanish begin',
#  'well im gon na finish bath goodfin night',
#  'let know youv got money carlo make call',
#  'u still go mall',
#  'turn friend stay whole show wont back til ltgt feel free go ahead smoke ltgt worth',
#  'text doesnt repli let know log',
#  'hi spoke maneesha v wed like know satisfi experi repli toll free yes',
#  'lift hope offer money need especi end month approach hurt studi anyway gr8 weekend',
#  'lol u trust',
#  'ok gentleman treat digniti respect',
#  'guy close',
#  'go noth greatby',
#  'hello handsom find job lazi work toward get back net mummi where boytoy miss',
#  'haha awesom minut',
#  'pleas call custom servic repres freephon 0808 145 4742 9am11pm guarante 1000 cash 5000 prize',
#  'got xmas radio time get',
#  'jus reach home go bath first sis use net tell u finish k',
#  'uniqu enough find 30th august wwwareyouuniquecouk',
#  'im sorri ive join leagu peopl dont keep touch mean great deal friend time even great person cost great week',
#  'hi final complet cours',
#  'stop howev suggest stay someon abl give or everi stool',
#  'hope youv settl new school year wishin gr8 day',
#  'gud mrng dear hav nice day',
#  'u got person stori',
#  'hamster dead hey tmr meet 1pm orchard mrt',
#  'hi kate even hope see tomorrow bit bloodi babyjontet txt back u xxx',
#  'found enc ltgt',
#  'sent ltgt buck',
#  'hello darlin ive finish colleg txt u finish u love kate xxx',
#  'account refil success inr ltdecimalgt keralacircl prepaid account balanc rs ltdecimalgt transact id kr ltgt',
#  'goodmorn sleep ga',
#  'u call alter 11 ok',
#  'say like dat dun buy ericsson oso oredi lar',
#  'enter cabin pa said happi bday boss felt special askd 4 lunch lunch invit apart went',
#  'aight yo dat straight dogg',
#  'pleas give us connect today ltdecimalgt refund bill',
#  'shoot big load get readi',
#  'what bruv hope great break reward semest',
#  'home alway chat',
#  'kkgoodstudi well',
#  'yup noe leh',
#  'sound great home',
#  'final match head toward draw predict',
#  'tire havent slept well past night',
#  'easi ahsen got select mean good',
#  'take exam march 3',
#  'yeah think use gt atm regist sure there anyway help let know sure readi',
#  'ok prob take ur time',
#  'os call ubandu run without instal hard diskyou use os copi import file system give repair shop',
#  'sorri ill call later',
#  'u say leh cours noth happen lar say v romant jus bit lor thk e nite sceneri nice leh',
#  '500 new mobil 2004 must go txt nokia 89545 collect todayfrom 1 www4tcbiz 2optout 08718726270150gbpmtmsg18',
#  'would realli appreci call need someon talk',
#  'u meet ur dream partner soon ur career 2 flyng start 2 find free txt horo follow ur star sign e g horo ari',
#  'hey compani elama po mudyadhu',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happi morn',
#  'dear good morn',
#  'get gandhipuram walk cross cut road right side ltgt street road turn first right',
#  'dear go rubber place',
#  'sorri batteri die yeah im',
#  'yesher tv alway avail work place',
#  'text meet someon sexi today u find date even flirt u join 4 10p repli name age eg sam 25 18 msg recdthirtyeight penc',
#  'print oh ltgt come upstair',
#  'ill littl closer like bus stop street',
#  'youwhen wil reach',
#  'new theori argument win situat lose person dont argu ur friend kick amp say im alway correct',
#  'u 447801259231 secret admir look 2 make contact ufind rreveal think ur specialcal 09058094597',
#  'tomarrow final hear laptop case cant',
#  'pleassssssseeeee tel v avent done sportsx',
#  'okay shine meant sign sound better',
#  'although told u dat im baig face watch realli like e watch u gave cos fr u thanx 4 everyth dat uve done today im touch',
#  'u dont rememb old commerci',
#  'late said websit didnt dont slipper',
#  'ask call ok',
#  'kalli wont bat 2nd inning',
#  'didnt work oh ok goodnight ill fix readi time wake dear miss good night sleep',
#  'congratul ur award 500 cd voucher 125gift guarante free entri 2 100 wkli draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'ranjith cal drpd deeraj deepak 5min hold',
#  'wen ur lovabl bcum angri wid u dnt take serious coz angri childish n true way show deep affect care n luv kettoda manda nice day da',
#  'doinghow',
#  'up 3day also ship compani take 2wks way usp take week get lag may bribe nipost get stuff',
#  'im back lem know your readi',
#  'dont necessarili expect done get back though im headin',
#  'mmm yummi babe nice jolt suzi',
#  'lover need',
#  'tri contact repli offer video handset 750 anytim network min unlimit text camcord repli call 08000930705',
#  'im park next mini come today think',
#  'yup',
#  'anyway im go shop cos sis done yet dun disturb u liao',
#  'luton 0125698789 ring ur around h',
#  'hey realli horni want chat see nake text hot 69698 text charg 150pm unsubscrib text stop 69698',
#  'dint come us',
#  'wana plan trip sometm',
#  'sure yet still tri get hold',
#  'ur rington servic chang 25 free credit go club4mobilescom choos content stop txt club stop 87070 150pwk club4 po box1146 mk45 2wt',
#  'evo download flash jealous',
#  'rington club get uk singl chart mobil week choos top qualiti rington messag free charg',
#  'come mu sort narcot situat',
#  'night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay',
#  'hmv bonus special 500 pound genuin hmv voucher answer 4 easi question play send hmv 86688 infowww100percentrealcom',
#  'usf guess might well take 1 car',
#  'object bf come',
#  'thanx',
#  'tell rob mack gf theater',
#  'awesom ill see bit',
#  'sent type food like',
#  'done hand celebr full swing yet',
#  'got call tool',
#  'wen u miss someon person definit special u person special miss keepintouch gdeve',
#  'ok ask money far',
#  'oki',
#  'yeah think usual guy still pass last night get ahold anybodi let know ill throw',
#  'k might come tonight class let earli',
#  'ok',
#  'hi babi im cruisin girl friend r u 2 give call hour home that alright fone fone love jenni xxx',
#  'life mean lot love life love peopl life world call friend call world ge',
#  'dearshal mail tonitebusi streetshal updat toniteth look okvarunnathu edukkukaye raksha ollubut good one real sens',
#  'hey told name gautham ah',
#  'haf u found feel stupid da v cam work',
#  'oop 4 got bit',
#  'much buzi',
#  'accident delet messag resend pleas',
#  'tmobil custom may claim free camera phone upgrad pay go sim card loyalti call 0845 021 3680offer end 28thfebtc appli',
#  'unless situat go gurl would appropri',
#  'hurt teas make cri end life die plz keep one rose grave say stupid miss u nice day bslvyl',
#  'cant pick phone right pls send messag',
#  'need coffe run tomoc believ time week alreadi',
#  'awesom rememb last time got somebodi high first time diesel v',
#  'shit realli shock scari cant imagin second def night u think somewher could crash night save taxi',
#  'oh way food fridg want go meal tonight',
#  'womdarful actor',
#  'sms ac blind date 4u rodds1 21m aberdeen unit kingdom check httpimg sms acwicmb3cktz8r74 blind date send hide',
#  'yup remb think book',
#  'jos ask u wana meet',
#  'lol yes friendship hang thread caus u wont buy stuff',
#  'themob check newest select content game tone gossip babe sport keep mobil fit funki text wap 82468',
#  'garag key arent bookshelf',
#  'today accept dayu accept brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi',
#  'think ur smart win 200 week week quiz text play 85222 nowtc winnersclub po box 84 m26 3uz 16 gbp150week',
#  'say hell give call friend got money hes definit buy end week',
#  'hi way u 2day normal waythi real ur uniquei hope know u 4 rest mylif hope u find wot lost',
#  'made day great day',
#  'kkadvanc happi pongal',
#  'hmmm guess go 4 kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao',
#  'realli dude friend im afraid',
#  'decemb mobil 11mths entitl updat latest colour camera mobil free call mobil updat co free 08002986906',
#  'coffe cake guess',
#  'merri christma babe love ya kiss',
#  'hey dont go watch x men lunch haha',
#  'cud u tell ppl im gona b bit l8 cos 2 buse hav gon past cos full im still waitin 4 1 pete x',
#  'would great well guild could meet bristol road somewher get touch weekend plan take flight good week',
#  'problem',
#  'callsmessagesmiss call',
#  'hi dahow today class',
#  'id say that good sign well know track record read women',
#  'cool text your park',
#  'im read text sent meant joke read light',
#  'kkapo kgood movi',
#  'mayb could get book tomo return immedi someth',
#  'call germani 1 penc per minut call fix line via access number 0844 861 85 85 prepay direct access',
#  'chanc might evapor soon violat privaci steal phone number employ paperwork cool pleas contact report supervisor',
#  'valentin day special win 1000 quiz take partner trip lifetim send go 83600 150pmsg rcvd custcare08718720201',
#  'tadaaaaa home babe still',
#  'cool come havent wine dine',
#  'sleepingand surf',
#  'sorri ill call later',
#  'u call right call hand phone',
#  'ok that great thanx lot',
#  'take post come must 1000s text happi read one wiv hello carolin end favourit bless',
#  'u hide stranger',
#  'interest like',
#  'sister clear two round birla soft yesterday',
#  'gudnitetcpractic go',
#  'dis yiju jus saw ur mail case huim havent sent u num dis num',
#  'one small prestig problem',
#  'fanci shag dointerest sextextukcom txt xxuk suzi 69876 txts cost 150 per msg tncs websit x',
#  'check realli miss see jeremiah great month',
#  'nah cant help ive never iphon',
#  'your car hour half im go apeshit',
#  'today sorri day ever angri ever misbehav hurt plz plz slap urself bcoz ur fault im basic good',
#  'yo guy ever figur much need alcohol jay tri figur much safe spend weed',
#  'ltgt ish minut 5 minut ago wtf',
#  'thank callingforgot say happi onam sirjii fine rememb met insur personmeet qatar insha allahrakhesh ex tata aig join tisscotays',
#  'congratul ur award 500 cd voucher 125gift guarante free entri 2 100 wkli draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'ur cashbal current 500 pound maxim ur cashin send cash 86688 150pmsg cc 08708800282 hgsuite3422land roww1j6hl',
#  'im actor work work even sleep late sinc im unemploy moment alway sleep late your unemploy everi day saturday',
#  'hello got st andrewsboy long way cold keep post',
#  'ha ha cool cool chikku chikkudb',
#  'oh ok prob',
#  'check audrey status right',
#  'busi tri finish new year look forward final meet',
#  'good afternoon sunshin dawn day refresh happi aliv breath air smile think love alway',
#  'well know z take care worri',
#  'updatenow xmas offer latest motorola sonyericsson nokia free bluetooth doubl min 1000 txt orang call mobileupd8 08000839402 call2optoutf4q',
#  'discount code rp176781 stop messag repli stop wwwregalportfoliocouk custom servic 08717205546',
#  'wat uniform get',
#  'cool text your readi',
#  'hello boytoy geeee miss alreadi woke wish bed cuddl love',
#  'spoil bed well',
#  'im go bath msg next ltgt min',
#  'cant keep talk peopl sure pay agre price pls tell want realli buy much will pay',
#  'thank rington order refer t91 charg gbp 4 per week unsubscrib anytim call custom servic 09057039994',
#  'say happen',
#  'could seen mei didt recognis face',
#  'well there lot thing happen lindsay new year sigh bar ptbo blue heron someth go',
#  'keep payasam rinu bring',
#  'taught ranjith sir call sms like becaus hes verifi project prabu told today pa dont mistak',
#  'guess that worri must know there way bodi repair im quit sure shouldnt worri well take slow first test guid ovul relax noth youv said reason worri ill keep followin',
#  'yeah sure give coupl minut track wallet',
#  'hey leav big deal take care',
#  'hey late ah meet 945',
#  'doubl min txts 4 6month free bluetooth orang avail soni nokia motorola phone call mobileupd8 08000839402 call2optoutn9dx',
#  'took mr owl 3 lick',
#  'custom place call',
#  'mm time dont like fun',
#  '4mths half price orang line rental latest camera phone 4 free phone 11mths call mobilesdirect free 08000938767 updat or2stoptxt',
#  'yup lunch buffet u eat alreadi',
#  'huh late fr dinner',
#  'hey sat go intro pilat kickbox',
#  'morn ok',
#  'yes think offic lap room think that last day didnt shut',
#  'pick bout 730ish time go',
#  'perform award calcul everi two monthnot current one month period',
#  'actual sleep still might u call back text gr8 rock sis send u text wen wake',
#  'alway put busi put pictur ass facebook one open peopl ive ever met would think pictur room would hurt make feel violat',
#  'good even sir al salam wahleykkumshar happi newsbi grace god got offer tayseertissco joinedhop fineinshah allahmeet sometimerakheshvisitor india',
#  'hmmmkbut want chang field quick dai wan na get system administr network administr',
#  'free rington text first 87131 poli text get 87131 true tone help 0845 2814032 16 1st free tone 3x150pw end txt stop',
#  'dear chechi talk',
#  'hair cream ship',
#  'none that happen til get though',
#  'yep great loxahatche xmas tree burn ltgt start hour',
#  'haha get use drive usf man know lot stoner',
#  'well slight disastr class pm fav darl hope day ok coffe wld good cant stay late tomorrow time place alway',
#  'hello good week fanci drink someth later',
#  'headin toward busetop',
#  'messagesom text miss sendernam miss number miss sentdat miss miss u lot that everyth miss sent via fullonsmscom',
#  'come room point iron plan weekend',
#  'cos want thing',
#  'oki ill go yan jiu skip ard oso go cine den go mrt one blah blah blah',
#  'bring home wendi',
#  '100 date servic call 09064012103 box334sk38ch',
#  'whatsup dont u want sleep',
#  'alright new goal',
#  'free entri 250 week competit text word win 80086 18 tc wwwtxttowincouk',
#  'alright ill head minut text meet',
#  'send logo 2 ur lover 2 name join heart txt love name1 name2 mobno eg love adam eve 07123456789 87077 yahoo pobox36504w45wq txtno 4 ad 150p',
#  'yesfrom last week im take live call',
#  'someon contact date servic enter phone fanci find call landlin 09111032124 pobox12n146tf150p',
#  'siva hostel aha',
#  'urgent mobil number award 2000 prize guarante call 09058094455 land line claim 3030 valid 12hrs',
#  'send ur friend receiv someth ur voic speak express 1childish 2naughti 3sentiment 4rowdi 5ful attitud 6romant 7shi 8attract 9funni ltgt irrit ltgt lovabl repli',
#  'ok shell ok guess',
#  'aathiwher dear',
#  'pain urin thing els',
#  '7 esplanad mind give lift cos got car today',
#  'wnt buy bmw car urgentlyit vri urgentbut hv shortag ltgt lacsther sourc arng dis amt ltgt lacsthat prob',
#  'home watch tv lor',
#  'usual take fifteen fuck minut respond yes question',
#  'congrat nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3min vari mobil 16 close 300603 post bcm4284 ldn wc1n3xx',
#  'book ticket pongal',
#  'avail im like right around hillsborough amp ltgt th',
#  'messag sent askin ltgt dollar shoul pay ltgt ltgt',
#  'ask g iouri ive told stori like ten time alreadi',
#  'long applebe fuck take',
#  'hi hope u get txtjourney hasnt gdnow 50 min late think',
#  'like love arrang',
#  'yesh realli greatbhaji told kalli best cricket sachin worldveri tough get',
#  'suppos wake gt',
#  'oic saw tot din c found group liao',
#  'sorri ill call later',
#  'hey hey wereth monkeespeopl say monkeyaround howdi gorgeous howu doin foundurself jobyet sausagelov jen xxx',
#  'sorri batteri die come im get gram where place',
#  'well done blimey exercis yeah kinda rememb wot hmm',
#  'wont get concentr dear know mind everyth',
#  'lol made plan new year',
#  '10 min later k',
#  'hank lotsli',
#  'thank hope good day today',
#  'kkwhat detail want transferacc enough',
#  'ok tell stay yeah tough optimist thing improv month',
#  'loan purpos 500 75000 homeown tenant welcom previous refus still help call free 0800 1956669 text back help',
#  'si si think ill go make oreo truffl',
#  'look ami ure beauti intellig woman like u lot know u dont like like dont worri',
#  'hope that result consist intellig kind start ask practicum link keep ear open best ttyl',
#  '120 call cost guess isnt bad miss ya need ya want ya love ya',
#  'go thru differ feelingwav decis cope individualtim heal everyth believ',
#  'u go phone gon na die stay',
#  'great never better day give even reason thank god',
#  'upgrdcentr orang custom may claim free camera phone upgrad loyalti call 0207 153 9153 offer end 26th juli tcs appli optout avail',
#  'sorri ill call later ok bye',
#  'ok way railway',
#  'great princess love give receiv oral doggi style fave posit enjoy make love ltgt time per night',
#  'dont put stuff road keep get slipperi',
#  'go ride bike',
#  'yup need ill jus wait 4 e rain 2 stop',
#  'mani compani tell languag',
#  'okmail dear dave final notic collect 4 tenerif holiday 5000 cash award call 09061743806 landlin tcs sae box326 cw25wx 150ppm',
#  'long sinc scream princess',
#  'noth meant money enter account bank remov flat rate someon transfer ltgt account ltgt dollar got remov bank differ charg also differb sure trust 9ja person send account detail cos',
#  'want 2 get laid tonight want real dog locat sent direct 2 ur mob join uk largest dog network txting moan 69888nyt ec2a 31pmsg150p',
#  'nice line said broken heart plz dont cum 1 time infront wise trust u good 9t',
#  'ok im gon na head usf like fifteen minut',
#  'love aathilov u lot',
#  'tension ahwhat machiani problem',
#  'k pick anoth 8th your done',
#  'whenr guy get back g said think stay mcr',
#  'almost see u sec',
#  'yo carlo friend alreadi ask work weekend',
#  'watch tv lor',
#  'thank babi cant wait tast real thing',
#  'chang fb jaykwon thuglyf falconerf',
#  'win realli 1 side long time',
#  'free messag activ 500 free text messag repli messag word free term condit visit www07781482378com',
#  'dear reach railway happen',
#  'depend qualiti want type sent boy fade glori 6 want ralph mayb 2',
#  'think ive fix send test messag',
#  'sorri man account dri would want could trade back half could buy shit credit card',
#  'congrat 1 year special cinema pass 2 call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420ip45w 150pm dont miss',
#  'sorryin meet ill call later',
#  'class ltgt reunion',
#  'free nowcan call',
#  'got meh',
#  'nope think go monday sorri repli late',
#  'told accentur confirm true',
#  'kate jackson rec center 7ish right',
#  'dear reach room',
#  'fight world easi u either win lose bt fightng some1 close u dificult u lose u lose u win u still lose',
#  'come',
#  'check nuerologist',
#  'lolnic went fish water',
#  '123 congratul week competit draw u 1450 prize claim call 09050002311 b4280703 tcsstop sms 08718727868 18 150ppm',
#  'wait e car dat bore wat cos wait outsid got noth 2 home stuff watch tv wat',
#  'mayb westshor hyde park villag place near hous',
#  'know how anthoni bring money ive school fee pay rent stuff like that need help friend need',
#  'what signific',
#  'opinion 1 2 jada 3 kusruthi 4 lovabl 5 silent 6 spl charact 7 matur 8 stylish 9 simpl pls repli',
#  '8 latest gs still scroung ammo want give new ak tri',
#  'prabhaim sorydarealyfrm heart im sori',
#  'lol ok forgiven',
#  'nojst chang tat',
#  'guarante latest nokia phone 40gb ipod mp3 player 500 prize txt word collect 83355 ibhltd ldnw15h 150pmtmsgrcvd18',
#  'sno competit',
#  'boltblu tone 150p repli poli mono eg poly3 1 cha cha slide 2 yeah 3 slow jamz 6 toxic 8 come stop 4 tone txt',
#  'credit top httpwwwbubbletextcom renew pin tgxxrz',
#  'way transport less problemat sat night way u want ask n join bday feel free need know definit nos book fri',
#  'usual person unconsci that children adult may behav abnorm ill call',
#  'that ebay might less elsewher',
#  'shall come get pickl',
#  'gon na go get taco',
#  'that rude campus',
#  'urgent mobil award 2000 bonus caller prize 020903 2nd attempt contact call 08718729755 box95qu',
#  'hi wont b ard 4 christma enjoy n merri xmas',
#  'today offer claim ur 150 worth discount voucher text yes 85023 savamob member offer mobil cs 08717898035 300 sub 16 unsub repli x',
#  'yes pretti ladi like singl',
#  'reciev tone within next 24hrs term condit pleas see channel u teletext pg 750',
#  'jay say your doublefaggot',
#  'privat 2003 account statement 07815296484 show 800 unredeem sim point call 08718738001 identifi code 41782 expir 181104',
#  'todaysundaysunday holidayso work',
#  'gudnitetcpractic go',
#  'ill late',
#  'ive call hope l8r malaria know miss guy miss bani big pls give love especi great day',
#  'good afternoon love goe day hope mayb got lead job think boytoy send passion kiss across sea',
#  'probabl gon na see later tonight lt',
#  'mayb fat finger press button doesnt know',
#  'ummmmmaah mani mani happi return day dear sweet heart happi birthday dear',
#  'tirupur da start offic call',
#  'wwwapplausestorecom monthlysubscription50pmsg max6month tcsc web age16 2stop txt stop',
#  'famous quot develop abil listen anyth uncondit without lose temper self confid mean marri',
#  'go colleg pa els ill come self pa',
#  '4 oclock mine bash flat plan',
#  'girl stay bed girl doesnt need recoveri time id rather pass fun coop bed',
#  'special',
#  'know need get hotel got invit apologis cali sweet come english bloke weddin',
#  'sorri took long omw',
#  'wait ltgt min',
#  'ok give 5 minut think see btw your alibi cut hair whole time',
#  'imagin final get sink bath put pace mayb even eat left also imagin feel cage cock surround bath water remind alway own enjoy cuck',
#  'hurri ive weeddefici like three day',
#  'sure get acknowledg astound tactless general faggi demand blood oath fo',
#  'ok everi night take warm bath drink cup milk youll see work magic still need loos weight know',
#  'ill look fri pan case cheap book perhap that silli fri pan isnt like book',
#  'well uv caus mutat sunscreen like essenti theseday',
#  'lunchyou onlinewhi',
#  'know friend alreadi told',
#  'hi princess thank pic pretti',
#  'aiyo u alway c ex one dunno abt mei repli first time u repli fast lucki workin huh got bao ur sugardad ahge',
#  'hi msg meim offic',
#  'thanx 4 e browni v nice',
#  'geeeee love much bare stand',
#  'gent tri contact last weekend draw show 1000 prize guarante call 09064012160 claim code k52 valid 12hrs 150ppm',
#  'fuck babe miss alreadi know cant let send money toward net need want crave',
#  'ill call u 2mrw ninish address icki american freek wont stop callin 2 bad jen k eh',
#  'oooh bed ridden ey think',
#  'anyway go gym whatev love smile hope ok good day babe miss much alreadi',
#  'love daddi make scream pleasur go slap ass dick',
#  'wot u wan na missi',
#  'yar lor wait 4 mum 2 finish sch lunch lor whole morn stay home clean room room quit clean hee',
#  'know lab goggl went',
#  'open door',
#  'wait call',
#  'nope wait sch 4 daddi',
#  '1000 cash 2000 prize claim call09050000327',
#  'im tire argu week week want ill',
#  'wait 4 sch finish ard 5',
#  'mobil number 5000 claim call us back ring claim hot line 09050005321',
#  'arngd marriag u r walkin unfortunt snake bite u bt love marriag danc frnt snake amp sayin bite bite',
#  'huh earli dinner outsid izzit',
#  'ok anyway need chang said',
#  'tri contact repli offer 750 min 150 textand new video phone call 08002988890 repli free deliveri tomorrow',
#  'exwif abl kid want kid one day',
#  'how scotland hope show jjc tendenc take care live dream',
#  'tell u headach want use 1 hour sick time',
#  'dun thk ill quit yet hmmm go jazz yogasana oso go meet em lesson den',
#  'pete pleas ring meiv hard gotani credit',
#  'ya srsli better yi tho',
#  'im meet call later',
#  'ur chanc win 250 wkli shop spree txt shop 80878 tscs wwwtxt2shopcom custcar 08715705022 1x150pwk',
#  'special select receiv 2000 pound award call 08712402050 line close cost 10ppm 16 tcs appli ag promo',
#  'privat 2003 account statement 07753741225 show 800 unredeem point call 08715203677 identifi code 42478 expir 241004',
#  'still grand prix',
#  'met stranger choos friend long world stand friendship never end let friend forev gud nitz',
#  'great',
#  'gud mrng dear nice day',
#  'import custom servic announc call freephon 0800 542 0825',
#  'exhaust train morn much wine pie sleep well',
#  'im go buy mum present ar',
#  'mind blastin tsunami occur rajnik stop swim indian oceand',
#  'u send home first ok lor im readi yet',
#  'speak cash yet',
#  'happi come noon',
#  'meet lunch la',
#  'take care n get well soon',
#  'xclusiveclubsaisai 2morow 285 soire special zouk nichol parisfre rose 2 ladi info 0794674629107880867867',
#  'meant say cant wait see u get bore bridgwat banter',
#  'neva mind ok',
#  'fine imma get drink somethin want come find',
#  '22 day kick euro2004 u kept date latest news result daili remov send get txt stop 83222',
#  'valentin game send dis msg ur friend 5 answer r someon realli love u que colour suit bestrpli',
#  'mani depend',
#  'thanx4 today cer nice 2 catch ave 2 find time often oh well take care c u soonc',
#  'call said himthen choos futur',
#  'happi valentin day know earli hundr handsom beauti wish thought finish aunti uncl 1st',
#  'like v shock leh cos tell shuhui like tell leona also like dat almost know liao got ask abt ur reaction lor',
#  'famili happi',
#  'come n pick come immedi aft ur lesson',
#  'let snow let snow kind weather bring ppl togeth friendship grow',
#  'dear got ltgt dollar hi hi',
#  'good word word may leav u dismay mani time',
#  'make sure alex know birthday fifteen minut far your concern',
#  'sorri got thing may pub later',
#  'nah straight bring bud drink someth that actual littl use straight cash',
#  'haha good hear im offici paid market 8th',
#  'mani lick take get center tootsi pop',
#  'yup thk r e teacher said make face look longer darren ask 2 cut short',
#  'new textbuddi chat 2 horni guy ur area 4 25p free 2 receiv search postcod gaytextbuddycom txt one name 89693',
#  'today vodafon number end 4882 select receiv 350 award number match call 09064019014 receiv 350 award',
#  'pleas dont say like hi hi hi',
#  'thank u',
#  'oh forward messag thought send',
#  'got seventeen pound seven hundr ml hope ok',
#  'dear voucher holder 2 claim week offer pc go httpwwwetlpcoukexpressoff tscs apply2 stop text txt stop 80062',
#  'n funni',
#  'sweetheart hope kind day one load reason smile biola',
#  'login dat time dad fetch home',
#  'shower babi',
#  'askd u question hour answer',
#  'well imma definit need restock thanksgiv ill let know im',
#  'said kiss kiss cant sound effect gorgeous man isnt kind person need smile brighten day',
#  'probabl gon na swing wee bit',
#  'ya nice readi thursday',
#  'allo brave buse taken train triumph mean bham jolli good rest week',
#  'watch cartoon listen music amp eve go templ amp church u',
#  'mind ask happen dont say uncomfort',
#  'privat 2003 account statement show 800 unredeem point call 08715203694 identifi code 40533 expir 311004',
#  'prob send email',
#  '1000 cash 2000 prize claim call09050000327 tc rstm sw7 3ss 150ppm',
#  'that cool sometim slow gentl sonetim rough hard',
#  'im gon na say sorri would normal start panic time sorri see tuesday',
#  'wait know wesley town bet hella drug',
#  'fine miss much',
#  'u got person stori',
#  'tell drug dealer get impati',
#  'sun cant come earth send luv ray cloud cant come river send luv rain cant come meet u send care msg u gud evng',
#  'place man',
#  'doesnt make sens take unless free need know wikipediacom',
#  '88800 89034 premium phone servic call 08718711108',
#  'sea lay rock rock envelop envelop paper paper 3 word',
#  'mum repent',
#  'sorri go home first daddi come fetch later',
#  'leav de start prepar next',
#  'yes babi studi posit kama sutra',
#  'en chikku nang bakra msg kalstiyathen teacoffe',
#  'carlosl minut still need buy',
#  'pay ltdecimalgt lakh',
#  'good even ttyl',
#  'u receiv msg',
#  'ho ho big belli laugh see ya tomo',
#  'sms ac sun0819 post helloyou seem cool want say hi hi stop send stop 62468',
#  'get ur 1st rington free repli msg tone gr8 top 20 tone phone everi week 150 per wk 2 opt send stop 08452810071 16',
#  'ditto wont worri say anyth anymor like said last night whatev want ill peac',
#  'ive got ltgt way could pick',
#  'dont knw pa drink milk',
#  'mayb say hi find got card great escap wetherspoon',
#  'piggi r u awak bet ure still sleep im go 4 lunch',
#  'caus im freaki lol',
#  'miss call caus yell scrappi miss u cant wait u come home im lone today',
#  'hex place talk explain',
#  'log 4 wat sdryb8i',
#  'xy go 4 e lunch',
#  'hi im sue 20 year old work lapdanc love sex text live im bedroom text sue 89555 textoper g2 1da 150ppmsg 18',
#  'want ask wait 4 finish lect cos lect finish hour anyway',
#  'finish work yet',
#  'everi king cri babi everi great build map imprtant u r today u wil reach tomorw gud ni8',
#  'dearm cherthalain case u r come cochin pls call bfore u starti shall also reach accordinglyor tell day u r comingtmorow engag an holiday',
#  'thank love torch bold',
#  'forward 448712404000pleas call 08712404000 immedi urgent messag wait',
#  'farm open',
#  'sorri troubl u buy 4d dad 1405 1680 1843 2 big 1 small sat n sun thanx',
#  'sister law hope great month say hey abiola',
#  'purchas stuff today mail po box number',
#  'ah poop look like ill prob send laptop get fix cuz gpu problem',
#  'good good job like entrepreneur',
#  'aight close still around alex place',
#  'meet corpor st outsid gap see mind work',
#  'mum ask buy food home',
#  'ku also dont msg repli msg',
#  'much r will pay',
#  'sorri ill call later',
#  'import prevent dehydr give enough fluid',
#  'that bit weird even suppos happen good idea sure pub',
#  'true deari sat pray even felt soso smsd time',
#  'dont think get away trek long famili town sorri',
#  'wan na gym harri',
#  'quit late lar ard 12 anyway wun b drivin',
#  'review keep fantast nokia ngage game deck club nokia go 2 wwwcnupdatescomnewslett unsubscrib alert repli word',
#  '4mths half price orang line rental latest camera phone 4 free phone 11mths call mobilesdirect free 08000938767 updat or2stoptxt tcs',
#  'height confid aeronaut professor wer calld amp wer askd 2 sit aeroplan aftr sat wer told dat plane ws made student dey hurri plane bt 1 didnt move saidif made studentsthi wont even start datz confid',
#  'seem like weird time night g want come smoke day shitstorm attribut alway come make everyon smoke',
#  '08714712388 10am7pm cost 10p',
#  'save stress person dorm account send account detail money sent',
#  'also know lunch menu da know',
#  'stuff sell ill tell',
#  '449071512431 urgent 2nd attempt contact uu 1250 call 09071512433 b4 050703 tcsbcm4235wc1n3xx callcost 150ppm mobilesvari max7 50',
#  'book lesson msg call work sth im go get spec membership px3748',
#  'guarante 1000 cash 2000 prize claim yr prize call custom servic repres 08714712394 10am7pm',
#  'macha dont feel upseti assum mindsetbeliev one even wonder plan uslet life begin againcal anytim',
#  'oh send address',
#  'sfine anytim best',
#  'wondar full flim',
#  'ya even cooki jelli',
#  'world run stillmayb feel sameso itor admiti madthen correctionor let call lifeand keep run worldmay u r also runninglet run',
#  'got look scrumptious daddi want eat night long',
#  'cos lar im ba dao ok 1 pm lor u never ask go ah said u would ask fri said u ask today',
#  'alright omw got ta chang order half8th',
#  'exact anyway far jide studi visit',
#  'dunno u ask',
#  'email alertfrom jeri stewarts 2kbsubject lowcost prescripiton drvgsto listen email call 123',
#  'didnt spring come earli yay',
#  'lol wont feel bad use money take steak dinner',
#  'even u dont get troubl convincingjust tel twice tel neglect msgs dont c read itjust dont repli',
#  'leav qatar tonit search opportunityal went fastpl add ur prayer dearrakhesh',
#  'one talk',
#  'thank look realli appreci',
#  'hi custom loyalti offerth new nokia6650 mobil 10 txtauction txt word start 81151 get 4tctxt tc 150pmtmsg',
#  'wish',
#  'haha mayb ure rite u know well da feel like someon gd lor u faster go find one gal group attach liao',
#  'yes glad made',
#  'well littl time thing good time ahead',
#  'got room soon hadnt put clock back til 8 shout everyon get realis 7 wahay anoth hour bed',
#  'ok may free gym',
#  'men like shorter ladi gaze eye',
#  'dunno jus say go lido time 930',
#  'promis take good care princess run pleas send pic get chanc ttyl',
#  'u subscrib best mobil content servic uk 3 per 10 day send stop 82324 helplin 08706091795',
#  'reason weve spoken year anyway great week best exam',
#  'monday next week give full gist',
#  'realiz 40 year well thousand old ladi run around tattoo',
#  'import custom servic announc premier',
#  'dont gim lip caveboy',
#  'get librari',
#  'reali sorryi dont recognis number confus r u pleas',
#  'didnt holla',
#  'cant think anyon spare room top head',
#  'faith make thing possiblehop make thing worklov make thing beautifulmay three christmasmerri christma',
#  'u made appoint',
#  'call youcarlo isar phone vibrat act might hear text',
#  'romant pari 2 night 2 flight 79 book 4 next year call 08704439680tscs appli',
#  'grandma oh dear u still ill felt shit morn think hungov anoth night leav sat',
#  'urgent ur 500 guarante award still unclaim call 09066368327 closingdate040902 claimcod m39m51 150pmmorefrommobile2bremovedmobypobox734ls27yf',
#  'noth jus tot u would ask cos u ba gua went mt faber yest yest jus went alreadi mah today go jus call lor',
#  'wish famili merri x mas happi new year advanc',
#  'ur award citi break could win 200 summer shop spree everi wk txt store 88039 skilgm tscs087147403231winawkage16 150perwksub',
#  'im nt goin got somethin unless meetin 4 dinner lor haha wonder go tis time',
#  'sorri ill call later',
#  'cant pick phone right pls send messag',
#  'lol know theyr dramat school alreadi close tomorrow appar cant drive inch snow suppos get',
#  'get anywher damn job hunt',
#  'lol u drunkard hair moment yeah still 4 tonight wat plan',
#  'idc get weasel way shit twice row',
#  'wil ltgt minut got space',
#  'sleepingand surf',
#  'thank pick trash',
#  'dont go tell friend your sure want live smoke much spend hour beg come smoke',
#  'hi kate love see tonight ill phone tomorrow got sing guy gave card xxx',
#  'happi new year dear brother realli miss got number decid send text wish happi abiola',
#  'mean get door',
#  'opinion 1 2 jada 3 kusruthi 4 lovabl 5 silent 6 spl charact 7 matur 8 stylish 9 simpl pls repli',
#  'hmmm thought said 2 hour slave 3 late punish',
#  'beerag',
#  'import custom servic announc premier call freephon 0800 542 0578',
#  'dont think turn like randomlli within 5min open',
#  'suppos couldnt make shes still town though',
#  'time fix spell sometim get complet diff word go figur',
#  'ever thought live good life perfect partner txt back name age join mobil communiti 100psms',
#  '5 free top polyphon tone call 087018728737 nation rate get toppoli tune sent everi week text subpoli 81618 3 per pole unsub 08718727870',
#  'gud mrng dear hav nice day',
#  'hope enjoy game yesterday sorri ive touch pls know fond bein thot great week abiola',
#  'e best 4 ur drive tmr',
#  'ywhere u dogbreath sound like jan c that al',
#  'omg want scream weigh lost weight woohoo',
#  'general isnt one uncount noun u dictionari piec research',
#  'realli get hang around',
#  'orang custom may claim free camera phone upgrad loyalti call 0207 153 9996 offer end 14thmarch tcs appli optout availa',
#  'petey boy wherear friendsar thekingshead come canlov nic',
#  'ok msg u b4 leav hous',
#  'gim ltgt minut ago',
#  'last chanc claim ur 150 worth discount voucher today text shop 85023 savamob offer mobil cs savamob pobox84 m263uz 300 sub 16',
#  'appt lttimegt fault u dont listen told u twice',
#  'free 1st week no1 nokia tone 4 ur mobil everi week txt nokia 8077 get txting tell ur mate wwwgetzedcouk pobox 36504 w45wq 16 norm150pton',
#  'guarante 200 award even 1000 cashto claim ur award call free 08000407165 18 2 stop getstop 88222 php rg21 4jx',
#  'k ill 4',
#  'dled 3d imp',
#  'sure make sure know aint smokin yet',
#  'boooo alway work quit',
#  'take half day leav bec well',
#  'ugh dont wan na get bed warm',
#  'ssnervous ltgt',
#  'there ring come guy costum gift futur yowif hint hint',
#  'congratul ur award either 500 cd gift voucher free entri 2 100 week draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'borrow ur bag ok',
#  'u outbid simonwatson5120 shinco dvd plyr 2 bid visit sms acsmsreward 2 end bid notif repli end',
#  'where boytoy miss happen',
#  'lot use one babe model doesnt help youi bring hell match',
#  'also bring galileo dobbi',
#  'respond',
#  'boo babe u enjoyin yourjob u seem 2 b gettin well hunnyhop ure oktak care illspeak 2u soonlot lovem xxxx',
#  'good afternoon starshin how boytoy crave yet ach fuck sip cappuccino miss babe teas kiss',
#  'road cant txt',
#  'smsservic yourinclus text credit pls goto wwwcomuknet login 3qxj9 unsubscrib stop extra charg help 08702840625comuk 220cm2 9ae',
#  '25p 4 alfi moon children need song ur mob tell ur m8s txt tone chariti 8007 nokia poli chariti poli zed 08701417012 profit 2 chariti',
#  'good even ttyl',
#  'hmm bit piec lol sigh',
#  'hahahaus brain dear',
#  'hey got mail',
#  'sorri light turn green meant anoth friend want ltgt worth may around',
#  'thank yesterday sir wonder hope enjoy burial mojibiola',
#  'u secret admir reveal think u r special call 09065174042 opt repli reveal stop 150 per msg recd cust care 07821230901',
#  'hi mate rv u hav nice hol messag 3 say hello coz havent sent u 1 age start drive stay roadsrvx',
#  'dear voucher holder claim week offer pc pleas go httpwwwetlpcoukexpressoff tscs appli stop text txt stop 80062',
#  'thank much skype wit kz sura didnt get pleasur compani hope good weve given ultimatum oh countin aburo enjoy messag sent day ago',
#  'sure result offer',
#  'good morn dear great amp success day',
#  'want 750 anytim network min 150 text new video phone five pound per week call 08002888812 repli deliveri tomorrow',
#  'sir late pay rent past month pay ltgt charg felt would inconsider nag someth give great cost that didnt speak howev recess wont abl pay charg month henc askin well ahead month end pleas help thank',
#  'tri contact offer new video phone 750 anytim network min half price rental camcord call 08000930705 repli deliveri wed',
#  'last chanc 2 claim ur 150 worth discount voucherstext yes 85023 nowsavamobmemb offer mobil cs 08717898035 300 sub 16 remov txt x stop',
#  'luv u soo much u dont understand special u r 2 ring u 2morrow luv u xxx',
#  'pls send comprehens mail im pay much',
#  'prashanthettan mother pass away last night pray famili',
#  'urgent call 09066350750 landlin complimentari 4 ibiza holiday 10000 cash await collect sae tcs po box 434 sk3 8wp 150 ppm 18',
#  'kkwhen go',
#  'meanwhil shit suit xavier decid give us ltgt second warn samantha come play jay guitar impress shit also dont think doug realiz dont live anymor',
#  'stomach thru much trauma swear cant eat better lose weight',
#  'officewhat mattermsg nowi call break',
#  'yeah there bare enough room two us x mani fuck shoe sorri man see later',
#  'today offer claim ur 150 worth discount voucher text yes 85023 savamob member offer mobil cs 08717898035 300 sub 16 unsub repli x',
#  'u reach orchard alreadi u wan 2 go buy ticket first',
#  'real babi want bring inner tigress',
#  'da run activ full version da',
#  'ah poor babyhop urfeel bettersn luv probthat overdos work hey go care spk 2 u sn lot lovejen xxx',
#  'stop stori ive told ive return hes say order',
#  'talk sexi make new friend fall love world discreet text date servic text vip 83110 see could meet',
#  'go take babe',
#  'hai ana tomarrow come morn ltdecimalgt ill sathi go rto offic repli came home',
#  'spoon okay',
#  'say somebodi name tampa',
#  'work go min',
#  'brother genius',
#  'sorri guess whenev get hold connect mayb hour two ill text',
#  'u find time bus coz need sort stuff',
#  'dude ive see lotta corvett late',
#  'congratul ur award either yrs suppli cds virgin record mysteri gift guarante call 09061104283 tscs wwwsmsconet 150pm approx 3min',
#  'consid wall bunker shit import never play peac guess place high enough dont matter',
#  'privat 2003 account statement 07808 xxxxxx show 800 unredeem point call 08719899217 identifi code 41685 expir 071104',
#  'hello need posh bird chap user trial prod champney put need address dob asap ta r',
#  'u want xmas 100 free text messag new video phone half price line rental call free 0800 0721072 find',
#  'well offici philosoph hole u wan na call home readi save',
#  'go goodno problembut still need littl experi understand american custom voic',
#  'ill text drop x',
#  'ugh long day im exhaust want cuddl take nap',
#  'talk atleast day otherwis miss best friend world shakespear shesil ltgt',
#  'shop till u drop either 10k 5k 500 cash 100 travel voucher call 09064011000 ntt po box cr01327bt fixedlin cost 150ppm mobil vari',
#  'castor need see someth',
#  'sunshin quiz wkli q win top soni dvd player u know countri liverpool play mid week txt ansr 82277 150 sptyron',
#  'u secret admir look 2 make contact ufind rreveal think ur specialcal 09058094565',
#  'u secret admir look 2 make contact ufind rreveal think ur specialcal 09065171142stopsms08',
#  'remind download content alreadi paid goto httpdoit mymobi tv collect content',
#  'see knew give break time woul lead alway want miss curfew gon na gibe til one midnight movi gon na get til 2 need come home need getsleep anyth need b studdi ear train',
#  'love give massag use lot babi oil fave posit',
#  'dude go sup',
#  'yoyyooo u know chang permiss drive mac usb flash drive',
#  'gibb unsoldmik hussey',
#  'like talk pa abl dont know',
#  'dun cut short leh u dun like ah fail shes quit sad',
#  'unbeliev faglord',
#  'wifehow knew time murder exact',
#  'ask princess',
#  'great princess think',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie',
#  'ok noe ure busi im realli bore msg u oso dunno wat colour choos 4 one',
#  'doesnt g class earli tomorrow thus shouldnt tri smoke ltgt',
#  'superb thought grate u dont everyth u want mean u still opportun happier tomorrow u today',
#  'hope good week check',
#  'im use hope agent dont drop sinc ive book thing year whole boston nyc experi',
#  'thursday night yeah sure thing well work',
#  'free rington wait collect simpli text password mix 85069 verifi get usher britney fml po box 5249 mk17 92h 450ppw 16',
#  'probabl money worri thing come due sever outstand invoic work two three month ago',
#  'possibl teach',
#  'wonder phone batteri went dead tell love babe',
#  'love smell bus aint tobacco',
#  'get worri derek taylor alreadi assum worst',
#  'hey what charl sorri late repli',
#  'lastest stereophon marley dizze racal libertin stroke win nookii game flirt click themob wap bookmark text wap 82468',
#  'ill give plus said grinul greet whenev speak',
#  'white fudg oreo store',
#  'januari male sale hot gay chat cheaper call 08709222922 nation rate 15pmin cheap 78pmin peak stop text call 08712460324 10pmin',
#  'love come took long leav zaher got word ym happi see sad left miss',
#  'sorri hurt',
#  'cant feel nauseous im piss didnt eat sweet week caus today plan pig diet week im hungri',
#  'ok lor earli still project meet',
#  'call da wait call',
#  'could ask carlo could get anybodi els chip',
#  'actual send remind today wonder weekend',
#  'peopl see msgs think iam addict msging wrong bcoz dont know iam addict sweet friend bslvyl',
#  'hey gave photo regist drive ah tmr wan na meet yck',
#  'dont talk ever ok word',
#  'u wana see',
#  'way school pls send ashley number',
#  'shall fine avalarr hollalat',
#  'went attend anoth two round todaybut still didt reach home',
#  'actual delet old websitenow blog magicalsongsblogspotcom',
#  'k wait chikkuil send aftr ltgt min',
#  'im diet ate 1 mani slice pizza yesterday ugh im alway diet',
#  'ki give kvb acc detail',
#  'oh come ah',
#  'money r lucki winner 2 claim prize text money 2 88600 1million give away ppt150x3normal text rate box403 w1t1ji',
#  'im realli sorri wont b abl 2 fridayhop u find alternativehop yr term go ok',
#  'congratul ore mo owo wa enjoy wish mani happi moment fro wherev go',
#  'samus shoulder yet',
#  'time think youll need know near campus',
#  'dear matthew pleas call 09063440451 landlin complimentari 4lux tenerif holiday 1000 cash await collect ppm150 sae tcs box334 sk38xh',
#  'dun wear jean lor',
#  'sinc side fever vomitin',
#  'kkare colleg',
#  'urgent call 09061749602 landlin complimentari 4 tenerif holiday 10000 cash await collect sae tcs box 528 hp20 1yf 150ppm 18',
#  'better made friday stuf like pig yesterday feel bleh least writh pain kind bleh',
#  'sell well ton coin sell coin someon thru paypal voila money back life pocket',
#  'theyr lot place hospit medic place safe',
#  'get touch folk wait compani txt back name age opt enjoy communiti 150psms',
#  'also ive sorta blown coupl time recent id rather text blue look weed',
#  'sent score sopha secondari applic school think think appli research cost also contact joke ogunrind school one less expens one',
#  'cant wait see photo use',
#  'ur cashbal current 500 pound maxim ur cashin send go 86688 150pmsg cc 08718720201 po box 11414 tcrw1',
#  'hey book kb sat alreadi lesson go ah keep sat night free need meet confirm lodg',
#  'chk ur belovd ms dict',
#  'time want come',
#  'awesom lem know whenev your around',
#  'shb b ok lor thanx',
#  'beauti truth graviti read care heart feel light someon feel heavi someon leav good night',
#  'also rememb get dobbi bowl car',
#  'filthi stori girl wait',
#  'sorri c ur msg yar lor poor thing 4 one night tmr ull brand new room 2 sleep',
#  'love isnt decis feel could decid love life would much simpler less magic',
#  'welp appar retir',
#  'sort code acc bank natwest repli confirm ive sent right person',
#  '',
#  'u sure u cant take sick time',
#  'urgent tri contact u today draw show 800 prize guarante call 09050001808 land line claim m95 valid12hr',
#  'watch cartoon listen music amp eve go templ amp church u',
#  'yo chad gymnast class wan na take site say christian class full',
#  'much buzi',
#  'better still catch let ask sell ltgt',
#  'sure night menu know noon menu',
#  'u want come backa beauti necklac token heart youthat give wife likingb seeno one give thatdont call mei wait till come',
#  'will go aptitud class',
#  'wont b 215 tri 2 sort hous ok',
#  'yar lor wan 2 go c hors race today mah eat earlier lor ate chicken rice u',
#  'haha awesom omw back',
#  'yup thk e shop close lor',
#  'account number',
#  'eh u send wrong lar',
#  'hey ad crap nite borin without ya 2 boggi u bore biatch thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont hesit know second time weak like keep notebook eat day anyth chang day sure noth',
#  'hey pay salari de ltgt',
#  'anoth month need chocol weed alcohol',
#  'start search get job daysh great potenti talent',
#  'reckon need town eightish walk carpark',
#  'congrat 2 mobil 3g videophon r call 09063458130 videochat wid mate play java game dload polyph music nolin rentl',
#  'look fuckin time fuck think',
#  'yo guess drop',
#  'carlo say hell mu ltgt minut',
#  'im offic call ltgt min',
#  'geeee miss alreadi know think fuck cant wait till next year togeth love kiss',
#  'yun ahth ubi one say wan call tomorrowcal 67441233 look ireneer got bus822656166382 ubi cresubi tech park6ph 1st 5wkg daysn',
#  'ugh got ta drive back sd la butt sore',
#  '26th juli',
#  'hi im relax time ever get 7am everi day parti good night get home tomorrow 5ish',
#  'wan come come lor din c stripe skirt',
#  'xmas stori peac xmas msg love xmas miracl jesus hav bless month ahead amp wish u merri xmas',
#  'cant dont number',
#  'chang e one next escal',
#  'yetund im class run water make ok pls',
#  'lot happen feel quiet beth aunt charli work lot helen mo',
#  'wait 4 bus stop aft ur lect lar dun c go get car come back n pick',
#  ...]

# %%
corpus_lemmatized=[]
for msg in messages['message']:
    sent=process_text_lemmatization(msg)
    corpus_lemmatized.append(sent)

# %%
corpus_lemmatized
# Out:
# ['go jurong point crazy available bugis n great world la e buffet cine got amore wat',
#  'ok lar joking wif u oni',
#  'free entry 2 wkly comp win fa cup final tkts 21st may 2005 text fa 87121 receive entry questionstd txt ratetcs apply 08452810075over18s',
#  'u dun say early hor u c already say',
#  'nah dont think go usf life around though',
#  'freemsg hey darling 3 week word back id like fun still tb ok xxx std chgs send 150 rcv',
#  'even brother like speak treat like aid patent',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press 9 copy friend callertune',
#  'winner valued network customer selected receivea 900 prize reward claim call 09061701461 claim code kl341 valid 12 hour',
#  'mobile 11 month u r entitled update latest colour mobile camera free call mobile update co free 08002986030',
#  'im gon na home soon dont want talk stuff anymore tonight k ive cried enough today',
#  'six chance win cash 100 20000 pound txt csh11 send 87575 cost 150pday 6days 16 tsandcs apply reply hl 4 info',
#  'urgent 1 week free membership 100000 prize jackpot txt word claim 81010 tc wwwdbuknet lccltd pobox 4403ldnw1a7rw18',
#  'ive searching right word thank breather promise wont take help granted fulfil promise wonderful blessing time',
#  'date sunday',
#  'xxxmobilemovieclub use credit click wap link next txt message click httpwap xxxmobilemovieclubcomnqjkgighjjgcbl',
#  'oh kim watching',
#  'eh u remember 2 spell name yes v naughty make v wet',
#  'fine thats way u feel thats way gota b',
#  'england v macedonia dont miss goalsteam news txt ur national team 87077 eg england 87077 trywales scotland 4txt120 poboxox36504w45wq 16',
#  'seriously spell name',
#  'im going try 2 month ha ha joking',
#  'pay first lar da stock comin',
#  'aft finish lunch go str lor ard 3 smth lor u finish ur lunch already',
#  'ffffffffff alright way meet sooner',
#  'forced eat slice im really hungry tho suck mark getting worried know im sick turn pizza lol',
#  'lol always convincing',
#  'catch bus frying egg make tea eating mom left dinner feel love',
#  'im back amp packing car ill let know there room',
#  'ahhh work vaguely remember feel like lol',
#  'wait thats still clear sure sarcastic thats x doesnt want live u',
#  'yeah got 2 v apologetic n fallen actin like spoilt child got caught till 2 wont go badly cheer',
#  'k tell anything',
#  'fear fainting housework quick cuppa',
#  'thanks subscription ringtone uk mobile charged 5month please confirm replying yes reply charged',
#  'yup ok go home look timing msg xuhui going learn 2nd may lesson 8am',
#  'oops ill let know roommate done',
#  'see letter b car',
#  'anything lor u decide',
#  'hello hows saturday go texting see youd decided anything tomo im trying invite anything',
#  'pls go ahead watt wanted sure great weekend abiola',
#  'forget tell want need crave love sweet arabian steed mmmmmm yummy',
#  '07732584351 rodger burn msg tried call reply sm free nokia mobile free camcorder please call 08000930705 delivery tomorrow',
#  'seeing',
#  'great hope like man well endowed ltgt inch',
#  'callsmessagesmissed call',
#  'didnt get hep b immunisation nigeria',
#  'fair enough anything going',
#  'yeah hopefully tyler cant could maybe ask around bit',
#  'u dont know stubborn didnt even want go hospital kept telling mark im weak sucker hospital weak sucker',
#  'thinked first time saw class',
#  'gram usually run like ltgt half eighth smarter though get almost whole second gram ltgt',
#  'k fyi x ride early tomorrow morning he crashing place tonight',
#  'wow never realized embarassed accomodations thought liked since best could always seemed happy cave im sorry didnt dont give im sorry offered im sorry room embarassing',
#  'sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end reply end sptv',
#  'know mallika sherawat yesterday find lturlgt',
#  'congrats 1 year special cinema pas 2 call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420ip45we 150pm dont miss',
#  'sorry ill call later meeting',
#  'tell reached',
#  'yesgauti sehwag odi series',
#  'gon na pick 1 burger way home cant even move pain killing',
#  'ha ha ha good joke girl situation seeker',
#  'part checking iq',
#  'sorry roommate took forever ok come',
#  'ok lar double check wif da hair dresser already said wun cut v short said cut look nice',
#  'valued customer pleased advise following recent review mob awarded 1500 bonus prize call 09066364589',
#  'today song dedicated day song u dedicate send ur valuable frnds first rply',
#  'urgent ur awarded complimentary trip eurodisinc trav acoentry41 1000 claim txt dis 87121 186150morefrmmob shracomorsglsuplt10 ls1 3aj',
#  'hear new divorce barbie come ken stuff',
#  'plane give month end',
#  'wah lucky man save money hee',
#  'finished class',
#  'hi babe im home wan na something xx',
#  'kkwhere youhow performed',
#  'u call',
#  'waiting machan call free',
#  'thats cool gentleman treat dignity respect',
#  'like people much shy pa',
#  'operate ltgt',
#  'still looking job much ta earn',
#  'sorry ill call later',
#  'k call ah',
#  'ok way home hi hi',
#  'place man',
#  'yup next stop',
#  'call later dont network urgnt sm',
#  'real u getting yo need 2 ticket one jacket im done already used multis',
#  'yes started send request make pain came back im back bed double coin factory got ta cash nitros',
#  'im really still tonight babe',
#  'ela kanoil download come wen ur free',
#  'yeah dont stand close tho youll catch something',
#  'sorry pain ok meet another night spent late afternoon casualty mean havent done stuff42moro includes time sheet sorry',
#  'smile pleasure smile pain smile trouble pours like rain smile sum1 hurt u smile becoz someone still love see u smiling',
#  'please call customer service representative 0800 169 6031 10am9pm guaranteed 1000 cash 5000 prize',
#  'havent planning buy later check already lido got 530 show e afternoon u finish work already',
#  'free ringtone waiting collected simply text password mix 85069 verify get usher britney fml po box 5249 mk17 92h 450ppw 16',
#  'watching telugu moviewat abt u',
#  'see finish load loan pay',
#  'hi wk ok hols yes bit run forgot hairdresser appointment four need get home n shower beforehand cause prob u',
#  'see cup coffee animation',
#  'please dont text anymore nothing else say',
#  'okay name ur price long legal wen pick u ave x am xx',
#  'im still looking car buy gone 4the driving test yet',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press 9 copy friend callertune',
#  'wow youre right didnt mean guess gave boston men changed search location nyc something changed cuz signin page still say boston',
#  'umma life vava umma love lot dear',
#  'thanks lot wish birthday thanks making birthday truly memorable',
#  'aight ill hit get cash',
#  'would ip address test considering computer isnt minecraft server',
#  'know grumpy old people mom like better lying always one play joke',
#  'dont worry guess he busy',
#  'plural noun research',
#  'going dinnermsg',
#  'im ok wif co like 2 try new thing scared u dun like mah co u said loud',
#  'gent trying contact last weekend draw show 1000 prize guaranteed call 09064012160 claim code k52 valid 12hrs 150ppm',
#  'wa ur openin sentence formal anyway im fine juz tt im eatin much n puttin weighthaha anythin special happened',
#  'entered cabin pa said happy bday bos felt special askd 4 lunch lunch invited apartment went',
#  'winner u specially selected 2 receive 1000 4 holiday flight inc speak live operator 2 claim 0871277810910pmin 18',
#  'goodo yes must speak friday eggpotato ratio tortilla needed',
#  'hmmmy uncle informed he paying school directly pls buy food',
#  'private 2004 account statement 07742676969 show 786 unredeemed bonus point claim call 08719180248 identifier code 45239 expires',
#  'urgent mobile awarded 2000 bonus caller prize 5903 final try contact u call landline 09064019788 box42wr29c 150ppm',
#  'new address applespairsall malarky',
#  'today voda number ending 7548 selected receive 350 award match please call 08712300220 quoting claim code 4041 standard rate app',
#  'going sao mu today done 12',
#  'predict wat time finish buying',
#  'good stuff',
#  'knowyetunde hasnt sent money yet sent text bother sending dont involve anything shouldnt imposed anything first place apologise',
#  'room',
#  'hey girl r u hope u r well del r bak long time c give call sum time lucyxx',
#  'kkhow much cost',
#  'im home',
#  'dear call tmorrowpls accomodate',
#  'first answer question',
#  'sunshine quiz wkly q win top sony dvd player u know country algarve txt ansr 82277 150 sptyrone',
#  'want 2 get laid tonight want real dogging location sent direct 2 ur mob join uk largest dogging network bt txting gravel 69888 nt ec2a 31pmsg150p',
#  'haf msn yijuehotmailcom',
#  'call meet',
#  'check room befor activity',
#  'youll rcv msg chat svc free hardcore service text go 69988 u get nothing u must age verify yr network try',
#  'got c lazy type forgot lect saw pouch like v nice',
#  'k text youre way',
#  'sir waiting mail',
#  'swt thought nver get tired little thing 4 lovable person cozsomtimes little thing occupy biggest part heart gud ni8',
#  'know pls open back',
#  'yes see ya dot',
#  'whats staff name taking class u',
#  'freemsg havent replied text im randy sexy female live local luv hear u netcollex ltd 08700621170150p per msg reply stop end',
#  'ummmawill call check inour life begin qatar pls pray hard',
#  'ki deleted contact',
#  'sindu got job birla soft',
#  'wine flowing im nevering',
#  'yup thk cine better co need 2 go 2 plaza mah',
#  'ok ur typical reply',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press 9 copy friend callertune',
#  'everywhere dirt floor window even shirt sometimes open mouth come flowing dream world without half chore time joy lot tv show ill see guess like thing must exist like rain hail mist time done become one',
#  'aaooooright work',
#  'im leaving house',
#  'hello love get interview today happy good boy think meare missing',
#  'customer service annoncement new year delivery waiting please call 07046744435 arrange delivery',
#  'winner u specially selected 2 receive 1000 cash 4 holiday flight inc speak live operator 2 claim 0871277810810',
#  'keep safe need miss already envy everyone see real life',
#  'new car house parentsi new job hand',
#  'im love im excited day spend make happy',
#  'pls stop bootydelious 32f inviting friend reply yes434 no434 see wwwsmsacubootydelious stop send stop frnd 62468',
#  'bangbabes ur order way u receive service msg 2 download ur content u goto wap bangb tv ur mobile internetservice menu',
#  'place ur point e culture module already',
#  'urgent trying contact last weekend draw show 900 prize guaranteed call 09061701939 claim code s89 valid 12hrs',
#  'hi frnd best way avoid missunderstding wit beloved one',
#  'great escape fancy bridge need lager see tomo',
#  'yes completely formclark also utter waste',
#  'sir need axis bank account bank address',
#  'hmmm thk sure got time hop ard ya go 4 free abt muz call u discus liao',
#  'time coming later',
#  'bloody hell cant believe forgot surname mr ill give u clue spanish begin',
#  'well im gon na finish bath goodfine night',
#  'let know youve got money carlos make call',
#  'u still going mall',
#  'turn friend staying whole show wont back til ltgt feel free go ahead smoke ltgt worth',
#  'text doesnt reply let know log',
#  'hi spoke maneesha v wed like know satisfied experience reply toll free yes',
#  'lifted hope offer money need especially end month approach hurt studying anyways gr8 weekend',
#  'lol u trust',
#  'ok gentleman treat dignity respect',
#  'guy close',
#  'going nothing greatbye',
#  'hello handsome finding job lazy working towards getting back net mummy wheres boytoy miss',
#  'haha awesome minute',
#  'please call customer service representative freephone 0808 145 4742 9am11pm guaranteed 1000 cash 5000 prize',
#  'got xmas radio time get',
#  'jus reached home go bathe first si using net tell u finish k',
#  'unique enough find 30th august wwwareyouuniquecouk',
#  'im sorry ive joined league people dont keep touch mean great deal friend time even great personal cost great week',
#  'hi finally completed course',
#  'stop however suggest stay someone able give or every stool',
#  'hope youve settled new school year wishin gr8 day',
#  'gud mrng dear hav nice day',
#  'u got person story',
#  'hamster dead hey tmr meet 1pm orchard mrt',
#  'hi kate evening hope see tomorrow bit bloody babyjontet txt back u xxx',
#  'found enc ltgt',
#  'sent ltgt buck',
#  'hello darlin ive finished college txt u finish u love kate xxx',
#  'account refilled successfully inr ltdecimalgt keralacircle prepaid account balance r ltdecimalgt transaction id kr ltgt',
#  'goodmorning sleeping ga',
#  'u call alter 11 ok',
#  'say like dat dun buy ericsson oso oredi lar',
#  'entered cabin pa said happy bday bos felt special askd 4 lunch lunch invited apartment went',
#  'aight yo dat straight dogg',
#  'please give u connection today ltdecimalgt refund bill',
#  'shoot big load get ready',
#  'whats bruv hope great break rewarding semester',
#  'home always chat',
#  'kkgoodstudy well',
#  'yup noe leh',
#  'sound great home',
#  'finally match heading towards draw prediction',
#  'tired havent slept well past night',
#  'easy ahsen got selected mean good',
#  'take exam march 3',
#  'yeah think use gt atm register sure there anyway help let know sure ready',
#  'ok prob take ur time',
#  'o called ubandu run without installing hard diskyou use o copy important file system give repair shop',
#  'sorry ill call later',
#  'u say leh course nothing happen lar say v romantic jus bit lor thk e nite scenery nice leh',
#  '500 new mobile 2004 must go txt nokia 89545 collect todayfrom 1 www4tcbiz 2optout 08718726270150gbpmtmsg18',
#  'would really appreciate call need someone talk',
#  'u meet ur dream partner soon ur career 2 flyng start 2 find free txt horo followed ur star sign e g horo aries',
#  'hey company elama po mudyadhu',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happy morning',
#  'dear good morning',
#  'get gandhipuram walk cross cut road right side ltgt street road turn first right',
#  'dear going rubber place',
#  'sorry battery died yeah im',
#  'yeshere tv always available work place',
#  'text meet someone sexy today u find date even flirt u join 4 10p reply name age eg sam 25 18 msg recdthirtyeight penny',
#  'printed oh ltgt come upstairs',
#  'ill little closer like bus stop street',
#  'youwhen wil reach',
#  'new theory argument win situation loses person dont argue ur friend kick amp say im always correct',
#  'u 447801259231 secret admirer looking 2 make contact ufind rreveal think ur specialcall 09058094597',
#  'tomarrow final hearing laptop case cant',
#  'pleassssssseeeeee tel v avent done sportsx',
#  'okay shining meant signing sound better',
#  'although told u dat im baig face watch really like e watch u gave co fr u thanx 4 everything dat uve done today im touched',
#  'u dont remember old commercial',
#  'late said website didnt dont slipper',
#  'asked call ok',
#  'kallis wont bat 2nd inning',
#  'didnt work oh ok goodnight ill fix ready time wake dearly missed good night sleep',
#  'congratulation ur awarded 500 cd voucher 125gift guaranteed free entry 2 100 wkly draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'ranjith cal drpd deeraj deepak 5min hold',
#  'wen ur lovable bcums angry wid u dnt take seriously coz angry childish n true way showing deep affection care n luv kettoda manda nice day da',
#  'doinghow',
#  'ups 3days also shipping company take 2wks way usps take week get lag may bribe nipost get stuff',
#  'im back lem know youre ready',
#  'dont necessarily expect done get back though im headin',
#  'mmm yummy babe nice jolt suzy',
#  'lover need',
#  'tried contact reply offer video handset 750 anytime network min unlimited text camcorder reply call 08000930705',
#  'im parked next mini coming today think',
#  'yup',
#  'anyway im going shopping co si done yet dun disturb u liao',
#  'luton 0125698789 ring ur around h',
#  'hey really horny want chat see naked text hot 69698 text charged 150pm unsubscribe text stop 69698',
#  'dint come u',
#  'wana plan trip sometme',
#  'sure yet still trying get hold',
#  'ur ringtone service changed 25 free credit go club4mobilescom choose content stop txt club stop 87070 150pwk club4 po box1146 mk45 2wt',
#  'evo download flash jealous',
#  'ringtone club get uk single chart mobile week choose top quality ringtone message free charge',
#  'come mu sorting narcotic situation',
#  'night ended another day morning come special way may smile like sunny ray leaf worry blue blue bay',
#  'hmv bonus special 500 pound genuine hmv voucher answer 4 easy question play send hmv 86688 infowww100percentrealcom',
#  'usf guess might well take 1 car',
#  'objection bf coming',
#  'thanx',
#  'tell rob mack gf theater',
#  'awesome ill see bit',
#  'sent type food like',
#  'done handed celebration full swing yet',
#  'got called tool',
#  'wen u miss someone person definitely special u person special miss keepintouch gdeve',
#  'ok asked money far',
#  'okie',
#  'yeah think usual guy still passed last night get ahold anybody let know ill throw',
#  'k might come tonight class let early',
#  'ok',
#  'hi baby im cruisin girl friend r u 2 give call hour home thats alright fone fone love jenny xxx',
#  'life mean lot love life love people life world call friend call world ge',
#  'dearshall mail tonitebusy streetshall update tonitethings looking okvarunnathu edukkukayee raksha ollubut good one real sense',
#  'hey told name gautham ah',
#  'haf u found feel stupid da v cam working',
#  'oops 4 got bit',
#  'much buzy',
#  'accidentally deleted message resend please',
#  'tmobile customer may claim free camera phone upgrade pay go sim card loyalty call 0845 021 3680offer end 28thfebtcs apply',
#  'unless situation go gurl would appropriate',
#  'hurt tease make cry end life die plz keep one rose grave say stupid miss u nice day bslvyl',
#  'cant pick phone right pls send message',
#  'need coffee run tomocant believe time week already',
#  'awesome remember last time got somebody high first time diesel v',
#  'shit really shocking scary cant imagine second def night u think somewhere could crash night save taxi',
#  'oh way food fridge want go meal tonight',
#  'womdarfull actor',
#  'sm ac blind date 4u rodds1 21m aberdeen united kingdom check httpimg sm acwicmb3cktz8r74 blind date send hide',
#  'yup remb think book',
#  'jos ask u wana meet',
#  'lol yes friendship hanging thread cause u wont buy stuff',
#  'themob check newest selection content game tone gossip babe sport keep mobile fit funky text wap 82468',
#  'garage key arent bookshelf',
#  'today accept dayu accept brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rply mean enemy',
#  'think ur smart win 200 week weekly quiz text play 85222 nowtcs winnersclub po box 84 m26 3uz 16 gbp150week',
#  'say hell give call friend got money he definitely buying end week',
#  'hi way u 2day normal waythis real ur uniquei hope know u 4 rest mylife hope u find wot lost',
#  'made day great day',
#  'kkadvance happy pongal',
#  'hmmm guess go 4 kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao',
#  'really dude friend im afraid',
#  'december mobile 11mths entitled update latest colour camera mobile free call mobile update co free 08002986906',
#  'coffee cake guess',
#  'merry christmas babe love ya kiss',
#  'hey dont go watch x men lunch haha',
#  'cud u tell ppl im gona b bit l8 co 2 bus hav gon past co full im still waitin 4 1 pete x',
#  'would great well guild could meet bristol road somewhere get touch weekend plan take flight good week',
#  'problem',
#  'callsmessagesmissed call',
#  'hi dahow today class',
#  'id say thats good sign well know track record reading woman',
#  'cool text youre parked',
#  'im reading text sent meant joke read light',
#  'kkapo kgood movie',
#  'maybe could get book tomo return immediately something',
#  'call germany 1 penny per minute call fixed line via access number 0844 861 85 85 prepayment direct access',
#  'chance might evaporated soon violated privacy stealing phone number employer paperwork cool please contact report supervisor',
#  'valentine day special win 1000 quiz take partner trip lifetime send go 83600 150pmsg rcvd custcare08718720201',
#  'tadaaaaa home babe still',
#  'cool come havent wined dined',
#  'sleepingand surfing',
#  'sorry ill call later',
#  'u calling right call hand phone',
#  'ok thats great thanx lot',
#  'take post come must 1000 text happy reading one wiv hello caroline end favourite bless',
#  'u hiding stranger',
#  'interested like',
#  'sister cleared two round birla soft yesterday',
#  'gudnitetcpractice going',
#  'dis yijue jus saw ur mail case huiming havent sent u num dis num',
#  'one small prestige problem',
#  'fancy shag dointerested sextextukcom txt xxuk suzy 69876 txts cost 150 per msg tncs website x',
#  'checking really miss seeing jeremiah great month',
#  'nah cant help ive never iphone',
#  'youre car hour half im going apeshit',
#  'today sorry day ever angry ever misbehaved hurt plz plz slap urself bcoz ur fault im basically good',
#  'yo guy ever figure much need alcohol jay trying figure much safely spend weed',
#  'ltgt ish minute 5 minute ago wtf',
#  'thank callingforgot say happy onam sirjii fine remembered met insurance personmeet qatar insha allahrakhesh ex tata aig joined tisscotayseer',
#  'congratulation ur awarded 500 cd voucher 125gift guaranteed free entry 2 100 wkly draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'ur cashbalance currently 500 pound maximize ur cashin send cash 86688 150pmsg cc 08708800282 hgsuite3422lands roww1j6hl',
#  'im actor work work evening sleep late since im unemployed moment always sleep late youre unemployed every day saturday',
#  'hello got st andrewsboy long way cold keep posted',
#  'ha ha cool cool chikku chikkudb',
#  'oh ok prob',
#  'check audreys status right',
#  'busy trying finish new year looking forward finally meeting',
#  'good afternoon sunshine dawn day refreshed happy alive breathe air smile think love always',
#  'well know z take care worry',
#  'updatenow xmas offer latest motorola sonyericsson nokia free bluetooth double min 1000 txt orange call mobileupd8 08000839402 call2optoutf4q',
#  'discount code rp176781 stop message reply stop wwwregalportfoliocouk customer service 08717205546',
#  'wat uniform get',
#  'cool text youre ready',
#  'hello boytoy geeee miss already woke wish bed cuddling love',
#  'spoil bed well',
#  'im going bath msg next ltgt min',
#  'cant keep talking people sure pay agree price pls tell want really buy much willing pay',
#  'thanks ringtone order reference t91 charged gbp 4 per week unsubscribe anytime calling customer service 09057039994',
#  'say happen',
#  'could seen mei didt recognise face',
#  'well there lot thing happening lindsay new year sigh bar ptbo blue heron something going',
#  'keep payasam rinu brings',
#  'taught ranjith sir called sm like becaus he verifying project prabu told today pa dont mistake',
#  'guess thats worried must know there way body repair im quite sure shouldnt worry well take slow first test guide ovulation relax nothing youve said reason worry ill keep followin',
#  'yeah sure give couple minute track wallet',
#  'hey leave big deal take care',
#  'hey late ah meet 945',
#  'double min txts 4 6months free bluetooth orange available sony nokia motorola phone call mobileupd8 08000839402 call2optoutn9dx',
#  'took mr owl 3 lick',
#  'customer place call',
#  'mm time dont like fun',
#  '4mths half price orange line rental latest camera phone 4 free phone 11mths call mobilesdirect free 08000938767 update or2stoptxt',
#  'yup lunch buffet u eat already',
#  'huh late fr dinner',
#  'hey sat going intro pilate kickboxing',
#  'morning ok',
#  'yes think office lap room think thats last day didnt shut',
#  'pick bout 730ish time going',
#  'performance award calculated every two monthnot current one month period',
#  'actually sleeping still might u call back text gr8 rock si send u text wen wake',
#  'always putting business put picture as facebook one open people ive ever met would think picture room would hurt make feel violated',
#  'good evening sir al salam wahleykkumsharing happy newsby grace god got offer tayseertissco joinedhope fineinshah allahmeet sometimerakheshvisitor india',
#  'hmmmkbut want change field quickly dai wan na get system administrator network administrator',
#  'free ringtone text first 87131 poly text get 87131 true tone help 0845 2814032 16 1st free tone 3x150pw end txt stop',
#  'dear chechi talk',
#  'hair cream shipped',
#  'none thats happening til get though',
#  'yep great loxahatchee xmas tree burning ltgt start hour',
#  'haha get used driving usf man know lot stoner',
#  'well slightly disastrous class pm fav darling hope day ok coffee wld good cant stay late tomorrow time place always',
#  'hello good week fancy drink something later',
#  'headin towards busetop',
#  'messagesome text missing sendername missing number missing sentdate missing missing u lot thats everything missing sent via fullonsmscom',
#  'come room point iron plan weekend',
#  'co want thing',
#  'okies ill go yan jiu skip ard oso go cine den go mrt one blah blah blah',
#  'bring home wendy',
#  '100 dating service call 09064012103 box334sk38ch',
#  'whatsup dont u want sleep',
#  'alright new goal',
#  'free entry 250 weekly competition text word win 80086 18 tc wwwtxttowincouk',
#  'alright ill head minute text meet',
#  'send logo 2 ur lover 2 name joined heart txt love name1 name2 mobno eg love adam eve 07123456789 87077 yahoo pobox36504w45wq txtno 4 ad 150p',
#  'yesfrom last week im taking live call',
#  'someone contacted dating service entered phone fancy find call landline 09111032124 pobox12n146tf150p',
#  'siva hostel aha',
#  'urgent mobile number awarded 2000 prize guaranteed call 09058094455 land line claim 3030 valid 12hrs',
#  'send ur friend receive something ur voice speaking expression 1childish 2naughty 3sentiment 4rowdy 5ful attitude 6romantic 7shy 8attractive 9funny ltgt irritating ltgt lovable reply',
#  'ok shell ok guess',
#  'aathiwhere dear',
#  'pain urination thing else',
#  '7 esplanade mind giving lift co got car today',
#  'wnt buy bmw car urgentlyits vry urgentbut hv shortage ltgt lacsthere source arng dis amt ltgt lacsthats prob',
#  'home watching tv lor',
#  'usually take fifteen fucking minute respond yes question',
#  'congrats nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3mins vary mobile 16 close 300603 post bcm4284 ldn wc1n3xx',
#  'booked ticket pongal',
#  'available im like right around hillsborough amp ltgt th',
#  'message sent askin ltgt dollar shoul pay ltgt ltgt',
#  'ask g iouri ive told story like ten time already',
#  'long applebees fucking take',
#  'hi hope u get txtjourney hasnt gdnow 50 min late think',
#  'like love arrange',
#  'yeshe really greatbhaji told kallis best cricketer sachin worldvery tough get',
#  'supposed wake gt',
#  'oic saw tot din c found group liao',
#  'sorry ill call later',
#  'hey hey werethe monkeespeople say monkeyaround howdy gorgeous howu doin foundurself jobyet sausagelove jen xxx',
#  'sorry battery died come im getting gram wheres place',
#  'well done blimey exercise yeah kinda remember wot hmm',
#  'wont get concentration dear know mind everything',
#  'lol made plan new year',
#  '10 min later k',
#  'hank lotsly',
#  'thanks hope good day today',
#  'kkwhat detail want transferacc enough',
#  'ok tell stay yeah tough optimistic thing improve month',
#  'loan purpose 500 75000 homeowner tenant welcome previously refused still help call free 0800 1956669 text back help',
#  'si si think ill go make oreo truffle',
#  'look amy ure beautiful intelligent woman like u lot know u dont like like dont worry',
#  'hope thats result consistently intelligent kind start asking practicum link keep ear open best ttyl',
#  '120 call cost guess isnt bad miss ya need ya want ya love ya',
#  'going thru different feelingwavering decision coping individualtime heal everything believe',
#  'u go phone gon na die stay',
#  'great never better day give even reason thank god',
#  'upgrdcentre orange customer may claim free camera phone upgrade loyalty call 0207 153 9153 offer end 26th july tc apply optout available',
#  'sorry ill call later ok bye',
#  'ok way railway',
#  'great princess love giving receiving oral doggy style fave position enjoy making love ltgt time per night',
#  'dont put stuff road keep getting slippery',
#  'going ride bike',
#  'yup need ill jus wait 4 e rain 2 stop',
#  'many company tell language',
#  'okmail dear dave final notice collect 4 tenerife holiday 5000 cash award call 09061743806 landline tc sae box326 cw25wx 150ppm',
#  'long since screamed princess',
#  'nothing meant money enters account bank remove flat rate someone transfered ltgt account ltgt dollar got removed bank differ charge also differbe sure trust 9ja person sending account detail co',
#  'want 2 get laid tonight want real dogging location sent direct 2 ur mob join uk largest dogging network txting moan 69888nyt ec2a 31pmsg150p',
#  'nice line said broken heart plz dont cum 1 time infront wise trust u good 9t',
#  'ok im gon na head usf like fifteen minute',
#  'love aathilove u lot',
#  'tension ahwhat machiany problem',
#  'k pick another 8th youre done',
#  'whenre guy getting back g said thinking staying mcr',
#  'almost see u sec',
#  'yo carlos friend already asking working weekend',
#  'watching tv lor',
#  'thank baby cant wait taste real thing',
#  'change fb jaykwon thuglyfe falconerf',
#  'win really 1 side long time',
#  'free message activate 500 free text message replying message word free term condition visit www07781482378com',
#  'dear reached railway happen',
#  'depends quality want type sent boye faded glory 6 want ralphs maybe 2',
#  'think ive fixed send test message',
#  'sorry man account dry would want could trade back half could buy shit credit card',
#  'congrats 1 year special cinema pas 2 call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420ip45we 150pm dont miss',
#  'sorryin meeting ill call later',
#  'class ltgt reunion',
#  'free nowcan call',
#  'got meh',
#  'nope think go monday sorry replied late',
#  'told accenture confirm true',
#  'kate jackson rec center 7ish right',
#  'dear reache room',
#  'fighting world easy u either win lose bt fightng some1 close u dificult u lose u lose u win u still lose',
#  'come',
#  'check nuerologist',
#  'lolnice went fish water',
#  '123 congratulation week competition draw u 1450 prize claim call 09050002311 b4280703 tcsstop sm 08718727868 18 150ppm',
#  'waiting e car dat bored wat co wait outside got nothing 2 home stuff watch tv wat',
#  'maybe westshore hyde park village place near house',
#  'know hows anthony bringing money ive school fee pay rent stuff like thats need help friend need',
#  'whats significance',
#  'opinion 1 2 jada 3 kusruthi 4 lovable 5 silent 6 spl character 7 matured 8 stylish 9 simple pls reply',
#  '8 latest g still scrounge ammo want give new ak try',
#  'prabhaim sorydarealyfrm heart im sory',
#  'lol ok forgiven',
#  'nojst change tat',
#  'guaranteed latest nokia phone 40gb ipod mp3 player 500 prize txt word collect 83355 ibhltd ldnw15h 150pmtmsgrcvd18',
#  'sno competition',
#  'boltblue tone 150p reply poly mono eg poly3 1 cha cha slide 2 yeah 3 slow jamz 6 toxic 8 come stop 4 tone txt',
#  'credit topped httpwwwbubbletextcom renewal pin tgxxrz',
#  'way transport less problematic sat night way u want ask n join bday feel free need know definite no booking fri',
#  'usually person unconscious thats child adult may behave abnormally ill call',
#  'thats ebay might less elsewhere',
#  'shall come get pickle',
#  'gon na go get taco',
#  'thats rude campus',
#  'urgent mobile awarded 2000 bonus caller prize 020903 2nd attempt contact call 08718729755 box95qu',
#  'hi wont b ard 4 christmas enjoy n merry xmas',
#  'today offer claim ur 150 worth discount voucher text yes 85023 savamob member offer mobile c 08717898035 300 sub 16 unsub reply x',
#  'yes pretty lady like single',
#  'recieve tone within next 24hrs term condition please see channel u teletext pg 750',
#  'jay say youre doublefaggot',
#  'private 2003 account statement 07815296484 show 800 unredeemed sim point call 08718738001 identifier code 41782 expires 181104',
#  'todaysundaysunday holidayso work',
#  'gudnitetcpractice going',
#  'ill late',
#  'ive called hoping l8r malaria know miss guy miss ban big pls give love especially great day',
#  'good afternoon love go day hope maybe got lead job think boytoy send passionate kiss across sea',
#  'probably gon na see later tonight lt',
#  'maybe fat finger press button doesnt know',
#  'ummmmmaah many many happy return day dear sweet heart happy birthday dear',
#  'tirupur da started office call',
#  'wwwapplausestorecom monthlysubscription50pmsg max6month tcsc web age16 2stop txt stop',
#  'famous quote develop ability listen anything unconditionally without losing temper self confidence mean married',
#  'going college pa else ill come self pa',
#  '4 oclock mine bash flat plan',
#  'girl stay bed girl doesnt need recovery time id rather pas fun cooped bed',
#  'special',
#  'know need get hotel got invitation apologise cali sweet come english bloke weddin',
#  'sorry took long omw',
#  'wait ltgt min',
#  'ok give 5 minute think see btw youre alibi cutting hair whole time',
#  'imagine finally get sink bath put pace maybe even eat left also imagine feel cage cock surrounded bath water reminding always owns enjoy cuck',
#  'hurry ive weeddeficient like three day',
#  'sure get acknowledgement astoundingly tactless generally faggy demand blood oath fo',
#  'ok every night take warm bath drink cup milk youll see work magic still need loose weight know',
#  'ill look frying pan case cheap book perhaps thats silly frying pan isnt likely book',
#  'well uv cause mutation sunscreen like essential thesedays',
#  'lunchyou onlinewhy',
#  'know friend already told',
#  'hi princess thank pic pretty',
#  'aiyo u always c ex one dunno abt mei reply first time u reply fast lucky workin huh got bao ur sugardad ahgee',
#  'hi msg meim office',
#  'thanx 4 e brownie v nice',
#  'geeeee love much barely stand',
#  'gent trying contact last weekend draw show 1000 prize guaranteed call 09064012160 claim code k52 valid 12hrs 150ppm',
#  'fuck babe miss already know cant let send money towards net need want crave',
#  'ill call u 2mrw ninish address icky american freek wont stop callin 2 bad jen k eh',
#  'oooh bed ridden ey thinking',
#  'anyways go gym whatever love smile hope ok good day babe miss much already',
#  'love daddy make scream pleasure going slap as dick',
#  'wot u wan na missy',
#  'yar lor wait 4 mum 2 finish sch lunch lor whole morning stay home clean room room quite clean hee',
#  'know lab goggles went',
#  'open door',
#  'waiting call',
#  'nope waiting sch 4 daddy',
#  '1000 cash 2000 prize claim call09050000327',
#  'im tired arguing week week want ill',
#  'wait 4 sch finish ard 5',
#  'mobile number 5000 claim call u back ring claim hot line 09050005321',
#  'arngd marriage u r walkin unfortuntly snake bite u bt love marriage dancing frnt snake amp sayin bite bite',
#  'huh early dinner outside izzit',
#  'ok anyway need change said',
#  'tried contact reply offer 750 min 150 textand new video phone call 08002988890 reply free delivery tomorrow',
#  'exwife able kid want kid one day',
#  'hows scotland hope showing jjc tendency take care live dream',
#  'tell u headache want use 1 hour sick time',
#  'dun thk ill quit yet hmmm go jazz yogasana oso go meet em lesson den',
#  'pete please ring meive hardly gotany credit',
#  'ya srsly better yi tho',
#  'im meeting call later',
#  'ur chance win 250 wkly shopping spree txt shop 80878 tscs wwwtxt2shopcom custcare 08715705022 1x150pwk',
#  'specially selected receive 2000 pound award call 08712402050 line close cost 10ppm 16 tc apply ag promo',
#  'private 2003 account statement 07753741225 show 800 unredeemed point call 08715203677 identifier code 42478 expires 241004',
#  'still grand prix',
#  'met stranger choose friend long world stand friendship never end let friend forever gud nitz',
#  'great',
#  'gud mrng dear nice day',
#  'important customer service announcement call freephone 0800 542 0825',
#  'exhausted train morning much wine pie sleep well',
#  'im going buy mum present ar',
#  'mind blastin tsunami occur rajnikant stopped swimming indian oceand',
#  'u sending home first ok lor im ready yet',
#  'speaking cash yet',
#  'happy come noon',
#  'meet lunch la',
#  'take care n get well soon',
#  'xclusiveclubsaisai 2morow 285 soiree speciale zouk nichols parisfree rose 2 lady info 0794674629107880867867',
#  'meant say cant wait see u getting bored bridgwater banter',
#  'neva mind ok',
#  'fine imma get drink somethin want come find',
#  '22 day kick euro2004 u kept date latest news result daily removed send get txt stop 83222',
#  'valentine game send dis msg ur friend 5 answer r someone really love u ques colour suit bestrply',
#  'many dependent',
#  'thanx4 today cer nice 2 catch ave 2 find time often oh well take care c u soonc',
#  'called said himthen choose future',
#  'happy valentine day know early hundred handsomes beauty wish thought finish aunty uncle 1st',
#  'like v shock leh co telling shuhui like telling leona also like dat almost know liao got ask abt ur reaction lor',
#  'family happiness',
#  'come n pick come immediately aft ur lesson',
#  'let snow let snow kind weather brings ppl together friendship grow',
#  'dear got ltgt dollar hi hi',
#  'good word word may leave u dismay many time',
#  'make sure alex know birthday fifteen minute far youre concerned',
#  'sorry got thing may pub later',
#  'nah straight bring bud drink something thats actually little useful straight cash',
#  'haha good hear im officially paid market 8th',
#  'many lick take get center tootsie pop',
#  'yup thk r e teacher said make face look longer darren ask 2 cut short',
#  'new textbuddy chat 2 horny guy ur area 4 25p free 2 receive search postcode gaytextbuddycom txt one name 89693',
#  'today vodafone number ending 4882 selected receive 350 award number match call 09064019014 receive 350 award',
#  'please dont say like hi hi hi',
#  'thank u',
#  'oh forwarded message thought send',
#  'got seventeen pound seven hundred ml hope ok',
#  'dear voucher holder 2 claim week offer pc go httpwwwetlpcoukexpressoffer tscs apply2 stop text txt stop 80062',
#  'n funny',
#  'sweetheart hope kind day one load reason smile biola',
#  'login dat time dad fetching home',
#  'shower baby',
#  'askd u question hour answer',
#  'well imma definitely need restock thanksgiving ill let know im',
#  'said kiss kiss cant sound effect gorgeous man isnt kind person need smile brighten day',
#  'probably gon na swing wee bit',
#  'ya nice ready thursday',
#  'allo braved bus taken train triumphed mean bham jolly good rest week',
#  'watching cartoon listening music amp eve go temple amp church u',
#  'mind ask happened dont say uncomfortable',
#  'private 2003 account statement show 800 unredeemed point call 08715203694 identifier code 40533 expires 311004',
#  'prob send email',
#  '1000 cash 2000 prize claim call09050000327 tc rstm sw7 3ss 150ppm',
#  'thats cool sometimes slow gentle sonetimes rough hard',
#  'im gon na say sorry would normal starting panic time sorry seeing tuesday',
#  'wait know wesley town bet hella drug',
#  'fine miss much',
#  'u got person story',
#  'tell drug dealer getting impatient',
#  'sun cant come earth send luv ray cloud cant come river send luv rain cant come meet u send care msg u gud evng',
#  'place man',
#  'doesnt make sense take unless free need know wikipediacom',
#  '88800 89034 premium phone service call 08718711108',
#  'sea lay rock rock envelope envelope paper paper 3 word',
#  'mum repent',
#  'sorry going home first daddy come fetch later',
#  'leave de start prepare next',
#  'yes baby study position kama sutra',
#  'en chikku nange bakra msg kalstiyathen teacoffee',
#  'carlosll minute still need buy',
#  'pay ltdecimalgt lakh',
#  'good evening ttyl',
#  'u receive msg',
#  'ho ho big belly laugh see ya tomo',
#  'sm ac sun0819 post helloyou seem cool wanted say hi hi stop send stop 62468',
#  'get ur 1st ringtone free reply msg tone gr8 top 20 tone phone every week 150 per wk 2 opt send stop 08452810071 16',
#  'ditto wont worry saying anything anymore like said last night whatever want ill peace',
#  'ive got ltgt way could pick',
#  'dont knw pa drink milk',
#  'maybe say hi find got card great escape wetherspoons',
#  'piggy r u awake bet ure still sleeping im going 4 lunch',
#  'cause im freaky lol',
#  'missed call cause yelling scrappy miss u cant wait u come home im lonely today',
#  'hex place talk explain',
#  'log 4 wat sdryb8i',
#  'xy going 4 e lunch',
#  'hi im sue 20 year old work lapdancer love sex text live im bedroom text sue 89555 textoperator g2 1da 150ppmsg 18',
#  'wanted ask wait 4 finish lect co lect finish hour anyway',
#  'finished work yet',
#  'every king cry baby every great building map imprtant u r today u wil reach tomorw gud ni8',
#  'dearme cherthalain case u r coming cochin pls call bfore u starti shall also reach accordinglyor tell day u r comingtmorow engaged an holiday',
#  'thanks love torch bold',
#  'forwarded 448712404000please call 08712404000 immediately urgent message waiting',
#  'farm open',
#  'sorry trouble u buy 4d dad 1405 1680 1843 2 big 1 small sat n sun thanx',
#  'sister law hope great month saying hey abiola',
#  'purchase stuff today mail po box number',
#  'ah poop look like ill prob send laptop get fixed cuz gpu problem',
#  'good good job like entrepreneur',
#  'aight close still around alexs place',
#  'meet corporation st outside gap see mind working',
#  'mum ask buy food home',
#  'ku also dont msg reply msg',
#  'much r willing pay',
#  'sorry ill call later',
#  'important prevent dehydration giving enough fluid',
#  'thats bit weird even supposed happening good idea sure pub',
#  'true deari sat pray evening felt soso smsd time',
#  'dont think get away trek long family town sorry',
#  'wan na gym harri',
#  'quite late lar ard 12 anyway wun b drivin',
#  'review keep fantastic nokia ngage game deck club nokia go 2 wwwcnupdatescomnewsletter unsubscribe alert reply word',
#  '4mths half price orange line rental latest camera phone 4 free phone 11mths call mobilesdirect free 08000938767 update or2stoptxt tc',
#  'height confidence aeronautics professor wer calld amp wer askd 2 sit aeroplane aftr sat wer told dat plane w made student dey hurried plane bt 1 didnt move saidif made studentsthis wont even start datz confidence',
#  'seems like weird timing night g want come smoke day shitstorm attributed always coming making everyone smoke',
#  '08714712388 10am7pm cost 10p',
#  'save stress person dorm account send account detail money sent',
#  'also know lunch menu da know',
#  'stuff sell ill tell',
#  '449071512431 urgent 2nd attempt contact uu 1250 call 09071512433 b4 050703 tcsbcm4235wc1n3xx callcost 150ppm mobilesvary max7 50',
#  'book lesson msg call work sth im going get spec membership px3748',
#  'guaranteed 1000 cash 2000 prize claim yr prize call customer service representative 08714712394 10am7pm',
#  'macha dont feel upseti assume mindsetbelieve one evening wonderful plan uslet life begin againcall anytime',
#  'oh send address',
#  'sfine anytime best',
#  'wondar full flim',
#  'ya even cooky jelly',
#  'world running stillmaybe feeling sameso itor admiti madthen correctionor let call lifeand keep running worldmay u r also runninglets run',
#  'got look scrumptious daddy want eat night long',
#  'co lar im ba dao ok 1 pm lor u never ask go ah said u would ask fri said u ask today',
#  'alright omw got ta change order half8th',
#  'exactly anyways far jide study visiting',
#  'dunno u ask',
#  'email alertfrom jeri stewartsize 2kbsubject lowcost prescripiton drvgsto listen email call 123',
#  'didnt spring coming early yay',
#  'lol wont feel bad use money take steak dinner',
#  'even u dont get trouble convincingjust tel twice tel neglect msg dont c read itjust dont reply',
#  'leaving qatar tonite search opportunityall went fastpls add ur prayer dearrakhesh',
#  'one talking',
#  'thanks looking really appreciate',
#  'hi customer loyalty offerthe new nokia6650 mobile 10 txtauction txt word start 81151 get 4tctxt tc 150pmtmsg',
#  'wish',
#  'haha mayb ure rite u know well da feeling liked someone gd lor u faster go find one gal group attached liao',
#  'yes glad made',
#  'well little time thing good time ahead',
#  'got room soon hadnt put clock back til 8 shouted everyone get realised 7 wahay another hour bed',
#  'ok may free gym',
#  'men like shorter lady gaze eye',
#  'dunno jus say go lido time 930',
#  'promise take good care princess run please send pic get chance ttyl',
#  'u subscribed best mobile content service uk 3 per 10 day send stop 82324 helpline 08706091795',
#  'reason weve spoken year anyways great week best exam',
#  'monday next week give full gist',
#  'realize 40 year well thousand old lady running around tattoo',
#  'important customer service announcement premier',
#  'dont gim lip caveboy',
#  'get library',
#  'realy sorryi dont recognise number confused r u please',
#  'didnt holla',
#  'cant think anyone spare room top head',
#  'faith make thing possiblehope make thing worklove make thing beautifulmay three christmasmerry christmas',
#  'u made appointment',
#  'call youcarlos isare phone vibrate acting might hear text',
#  'romantic paris 2 night 2 flight 79 book 4 next year call 08704439680tscs apply',
#  'grandma oh dear u still ill felt shit morning think hungover another night leave sat',
#  'urgent ur 500 guaranteed award still unclaimed call 09066368327 closingdate040902 claimcode m39m51 150pmmorefrommobile2bremovedmobypobox734ls27yf',
#  'nothing jus tot u would ask co u ba gua went mt faber yest yest jus went already mah today going jus call lor',
#  'wishing family merry x ma happy new year advance',
#  'ur awarded city break could win 200 summer shopping spree every wk txt store 88039 skilgme tscs087147403231winawkage16 150perwksub',
#  'im nt goin got somethin unless meetin 4 dinner lor haha wonder go ti time',
#  'sorry ill call later',
#  'cant pick phone right pls send message',
#  'lol know theyre dramatic school already closed tomorrow apparently cant drive inch snow supposed get',
#  'getting anywhere damn job hunting',
#  'lol u drunkard hair moment yeah still 4 tonight wats plan',
#  'idc get weaseling way shit twice row',
#  'wil ltgt minute got space',
#  'sleepingand surfing',
#  'thanks picking trash',
#  'dont go tell friend youre sure want live smoke much spend hour begging come smoke',
#  'hi kate lovely see tonight ill phone tomorrow got sing guy gave card xxx',
#  'happy new year dear brother really miss got number decided send text wishing happiness abiola',
#  'mean get door',
#  'opinion 1 2 jada 3 kusruthi 4 lovable 5 silent 6 spl character 7 matured 8 stylish 9 simple pls reply',
#  'hmmm thought said 2 hour slave 3 late punish',
#  'beerage',
#  'important customer service announcement premier call freephone 0800 542 0578',
#  'dont think turn like randomlly within 5min opening',
#  'supposed couldnt make shes still town though',
#  'time fix spelling sometimes get completely diff word go figure',
#  'ever thought living good life perfect partner txt back name age join mobile community 100psms',
#  '5 free top polyphonic tone call 087018728737 national rate get toppoly tune sent every week text subpoly 81618 3 per pole unsub 08718727870',
#  'gud mrng dear hav nice day',
#  'hoping enjoyed game yesterday sorry ive touch pls know fondly bein thot great week abiola',
#  'e best 4 ur driving tmr',
#  'ywhere u dogbreath sounding like jan c thats al',
#  'omg want scream weighed lost weight woohoo',
#  'generally isnt one uncountable noun u dictionary piece research',
#  'really getting hanging around',
#  'orange customer may claim free camera phone upgrade loyalty call 0207 153 9996 offer end 14thmarch tc apply optout availa',
#  'petey boy whereare friendsare thekingshead come canlove nic',
#  'ok msg u b4 leave house',
#  'gim ltgt minute ago',
#  'last chance claim ur 150 worth discount voucher today text shop 85023 savamob offer mobile c savamob pobox84 m263uz 300 sub 16',
#  'appt lttimegt fault u dont listen told u twice',
#  'free 1st week no1 nokia tone 4 ur mobile every week txt nokia 8077 get txting tell ur mate wwwgetzedcouk pobox 36504 w45wq 16 norm150ptone',
#  'guaranteed 200 award even 1000 cashto claim ur award call free 08000407165 18 2 stop getstop 88222 php rg21 4jx',
#  'k ill 4',
#  'dled 3d imp',
#  'sure make sure know aint smokin yet',
#  'boooo always work quit',
#  'taking half day leave bec well',
#  'ugh dont wan na get bed warm',
#  'ssnervous ltgt',
#  'there ring come guy costume gift future yowifes hint hint',
#  'congratulation ur awarded either 500 cd gift voucher free entry 2 100 weekly draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'borrow ur bag ok',
#  'u outbid simonwatson5120 shinco dvd plyr 2 bid visit sm acsmsrewards 2 end bid notification reply end',
#  'wheres boytoy miss happened',
#  'lot used one babe model doesnt help youi bring hell match',
#  'also bringing galileo dobby',
#  'responding',
#  'boo babe u enjoyin yourjob u seemed 2 b gettin well hunnyhope ure oktake care illspeak 2u soonlots loveme xxxx',
#  'good afternoon starshine hows boytoy crave yet ache fuck sip cappuccino miss babe teasing kiss',
#  'road cant txt',
#  'smsservices yourinclusive text credit pls goto wwwcomuknet login 3qxj9 unsubscribe stop extra charge help 08702840625comuk 220cm2 9ae',
#  '25p 4 alfie moon child need song ur mob tell ur m8s txt tone charity 8007 nokias poly charity polys zed 08701417012 profit 2 charity',
#  'good evening ttyl',
#  'hmm bit piece lol sigh',
#  'hahahause brain dear',
#  'hey got mail',
#  'sorry light turned green meant another friend wanted ltgt worth may around',
#  'thanks yesterday sir wonderful hope enjoyed burial mojibiola',
#  'u secret admirer reveal think u r special call 09065174042 opt reply reveal stop 150 per msg recd cust care 07821230901',
#  'hi mate rv u hav nice hol message 3 say hello coz havent sent u 1 age started driving stay roadsrvx',
#  'dear voucher holder claim week offer pc please go httpwwwetlpcoukexpressoffer tscs apply stop text txt stop 80062',
#  'thank much skyped wit kz sura didnt get pleasure company hope good weve given ultimatum oh countin aburo enjoy message sent day ago',
#  'surely result offer',
#  'good morning dear great amp successful day',
#  'want 750 anytime network min 150 text new video phone five pound per week call 08002888812 reply delivery tomorrow',
#  'sir late paying rent past month pay ltgt charge felt would inconsiderate nag something give great cost thats didnt speak however recession wont able pay charge month hence askin well ahead month end please help thanks',
#  'tried contact offer new video phone 750 anytime network min half price rental camcorder call 08000930705 reply delivery wed',
#  'last chance 2 claim ur 150 worth discount voucherstext yes 85023 nowsavamobmember offer mobile c 08717898035 300 sub 16 remove txt x stop',
#  'luv u soo much u dont understand special u r 2 ring u 2morrow luv u xxx',
#  'pls send comprehensive mail im paying much',
#  'prashanthettans mother passed away last night pray family',
#  'urgent call 09066350750 landline complimentary 4 ibiza holiday 10000 cash await collection sae tc po box 434 sk3 8wp 150 ppm 18',
#  'kkwhen going',
#  'meanwhile shit suite xavier decided give u ltgt second warning samantha coming playing jay guitar impress shit also dont think doug realizes dont live anymore',
#  'stomach thru much trauma swear cant eat better lose weight',
#  'officewhats mattermsg nowi call break',
#  'yeah there barely enough room two u x many fucking shoe sorry man see later',
#  'today offer claim ur 150 worth discount voucher text yes 85023 savamob member offer mobile c 08717898035 300 sub 16 unsub reply x',
#  'u reach orchard already u wan 2 go buy ticket first',
#  'real baby want bring inner tigress',
#  'da run activate full version da',
#  'ah poor babyhope urfeeling bettersn luv probthat overdose work hey go careful spk 2 u sn lot lovejen xxx',
#  'stop story ive told ive returned he saying order',
#  'talk sexy make new friend fall love world discreet text dating service text vip 83110 see could meet',
#  'going take babe',
#  'hai ana tomarrow coming morning ltdecimalgt ill sathy go rto office reply came home',
#  'spoon okay',
#  'say somebody named tampa',
#  'work going min',
#  'brother genius',
#  'sorry guess whenever get hold connection maybe hour two ill text',
#  'u find time bus coz need sort stuff',
#  'dude ive seeing lotta corvette lately',
#  'congratulation ur awarded either yr supply cd virgin record mystery gift guaranteed call 09061104283 tscs wwwsmsconet 150pm approx 3mins',
#  'consider wall bunker shit important never play peaceful guess place high enough dont matter',
#  'private 2003 account statement 07808 xxxxxx show 800 unredeemed point call 08719899217 identifier code 41685 expires 071104',
#  'hello need posh bird chap user trial prod champneys put need address dob asap ta r',
#  'u want xmas 100 free text message new video phone half price line rental call free 0800 0721072 find',
#  'well officially philosophical hole u wan na call home ready saved',
#  'going goodno problembut still need little experience understand american customer voice',
#  'ill text drop x',
#  'ugh long day im exhausted want cuddle take nap',
#  'talk atleast day otherwise miss best friend world shakespeare shesil ltgt',
#  'shop till u drop either 10k 5k 500 cash 100 travel voucher call 09064011000 ntt po box cr01327bt fixedline cost 150ppm mobile vary',
#  'castor need see something',
#  'sunshine quiz wkly q win top sony dvd player u know country liverpool played mid week txt ansr 82277 150 sptyrone',
#  'u secret admirer looking 2 make contact ufind rreveal think ur specialcall 09058094565',
#  'u secret admirer looking 2 make contact ufind rreveal think ur specialcall 09065171142stopsms08',
#  'reminder downloaded content already paid goto httpdoit mymoby tv collect content',
#  'see knew giving break time woul lead always wanting miss curfew gon na gibe til one midnight movie gon na get til 2 need come home need getsleep anything need b studdying ear training',
#  'love give massage use lot baby oil fave position',
#  'dude go sup',
#  'yoyyooo u know change permission drive mac usb flash drive',
#  'gibbs unsoldmike hussey',
#  'like talk pa able dont know',
#  'dun cut short leh u dun like ah failed shes quite sad',
#  'unbelievable faglord',
#  'wifehow knew time murder exactly',
#  'ask princess',
#  'great princess thinking',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie',
#  'ok noe ure busy im really bored msg u oso dunno wat colour choose 4 one',
#  'doesnt g class early tomorrow thus shouldnt trying smoke ltgt',
#  'superb thought grateful u dont everything u want mean u still opportunity happier tomorrow u today',
#  'hope good week checking',
#  'im used hope agent dont drop since ive booked thing year whole boston nyc experiment',
#  'thursday night yeah sure thing well work',
#  'free ringtone waiting collected simply text password mix 85069 verify get usher britney fml po box 5249 mk17 92h 450ppw 16',
#  'probably money worry thing coming due several outstanding invoice work two three month ago',
#  'possible teach',
#  'wonder phone battery went dead tell love babe',
#  'lovely smell bus aint tobacco',
#  'getting worried derek taylor already assumed worst',
#  'hey whats charles sorry late reply',
#  'lastest stereophonics marley dizzee racal libertine stroke win nookii game flirt click themob wap bookmark text wap 82468',
#  'ill give plus said grinule greet whenever speak',
#  'white fudge oreo store',
#  'january male sale hot gay chat cheaper call 08709222922 national rate 15pmin cheap 78pmin peak stop text call 08712460324 10pmin',
#  'love come took long leave zahers got word ym happy see sad left miss',
#  'sorry hurt',
#  'cant feel nauseous im pissed didnt eat sweet week cause today planning pig dieting week im hungry',
#  'ok lor early still project meeting',
#  'call da waiting call',
#  'could ask carlos could get anybody else chip',
#  'actually send reminder today wonderful weekend',
#  'people see msg think iam addicted msging wrong bcoz dont know iam addicted sweet friend bslvyl',
#  'hey gave photo registered driving ah tmr wan na meet yck',
#  'dont talk ever ok word',
#  'u wana see',
#  'way school pls send ashleys number',
#  'shall fine avalarr hollalater',
#  'went attend another two round todaybut still didt reach home',
#  'actually deleted old websitenow blogging magicalsongsblogspotcom',
#  'k wait chikkuil send aftr ltgt min',
#  'im diet ate 1 many slice pizza yesterday ugh im always diet',
#  'ki give kvb acc detail',
#  'oh come ah',
#  'money r lucky winner 2 claim prize text money 2 88600 1million give away ppt150x3normal text rate box403 w1t1jy',
#  'im really sorry wont b able 2 fridayhope u find alternativehope yr term going ok',
#  'congratulation ore mo owo wa enjoy wish many happy moment fro wherever go',
#  'samus shoulder yet',
#  'time think youll need know near campus',
#  'dear matthew please call 09063440451 landline complimentary 4lux tenerife holiday 1000 cash await collection ppm150 sae tc box334 sk38xh',
#  'dun wear jean lor',
#  'since side fever vomitin',
#  'kkare college',
#  'urgent call 09061749602 landline complimentary 4 tenerife holiday 10000 cash await collection sae tc box 528 hp20 1yf 150ppm 18',
#  'better made friday stuffed like pig yesterday feel bleh least writhing pain kind bleh',
#  'sell well ton coin sell coin someone thru paypal voila money back life pocket',
#  'theyre lot place hospital medical place safe',
#  'getting touch folk waiting company txt back name age opt enjoy community 150psms',
#  'also ive sorta blown couple time recently id rather text blue looking weed',
#  'sent score sophas secondary application school think thinking applying research cost also contact joke ogunrinde school one less expensive one',
#  'cant wait see photo useful',
#  'ur cashbalance currently 500 pound maximize ur cashin send go 86688 150pmsg cc 08718720201 po box 11414 tcrw1',
#  'hey booked kb sat already lesson going ah keep sat night free need meet confirm lodging',
#  'chk ur belovd m dict',
#  'time want come',
#  'awesome lem know whenever youre around',
#  'shb b ok lor thanx',
#  'beautiful truth gravity read carefully heart feel light someone feel heavy someone leaf good night',
#  'also remember get dobbys bowl car',
#  'filthy story girl waiting',
#  'sorry c ur msg yar lor poor thing 4 one night tmr ull brand new room 2 sleep',
#  'love isnt decision feeling could decide love life would much simpler less magical',
#  'welp apparently retired',
#  'sort code acc bank natwest reply confirm ive sent right person',
#  '',
#  'u sure u cant take sick time',
#  'urgent trying contact u today draw show 800 prize guaranteed call 09050001808 land line claim m95 valid12hrs',
#  'watching cartoon listening music amp eve go temple amp church u',
#  'yo chad gymnastics class wan na take site say christian class full',
#  'much buzy',
#  'better still catch let ask sell ltgt',
#  'sure night menu know noon menu',
#  'u want come backa beautiful necklace token heart youthats give wife likingbe seeno one give thatdont call mei wait till come',
#  'willing go aptitude class',
#  'wont b 215 trying 2 sort house ok',
#  'yar lor wan 2 go c horse racing today mah eat earlier lor ate chicken rice u',
#  'haha awesome omw back',
#  'yup thk e shop close lor',
#  'account number',
#  'eh u send wrongly lar',
#  'hey ad crap nite borin without ya 2 boggy u boring biatch thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont hesitate know second time weakness like keep notebook eat day anything changed day sure nothing',
#  'hey pay salary de ltgt',
#  'another month need chocolate weed alcohol',
#  'started searching get job dayshe great potential talent',
#  'reckon need town eightish walk carpark',
#  'congrats 2 mobile 3g videophones r call 09063458130 videochat wid mate play java game dload polyph music noline rentl',
#  'look fuckin time fuck think',
#  'yo guess dropped',
#  'carlos say hell mu ltgt minute',
#  'im office call ltgt min',
#  'geeee miss already know think fuck cant wait till next year together loving kiss',
#  'yun ahthe ubi one say wan call tomorrowcall 67441233 look ireneere got bus822656166382 ubi cresubi tech park6ph 1st 5wkg daysn',
#  'ugh got ta drive back sd la butt sore',
#  '26th july',
#  'hi im relaxing time ever get 7am every day party good night get home tomorrow 5ish',
#  'wan come come lor din c stripe skirt',
#  'xmas story peace xmas msg love xmas miracle jesus hav blessed month ahead amp wish u merry xmas',
#  'cant dont number',
#  'change e one next escalator',
#  'yetunde im class run water make ok pls',
#  'lot happened feel quiet beth aunt charlie working lot helen mo',
#  'wait 4 bus stop aft ur lect lar dun c go get car come back n pick',
#  ...]

# %% [markdown]
# ### Bag of words

# %%
### create bag of words model
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(binary=True,max_features=100)

# %%
X=cv.fit_transform(corpus_lemmatized).toarray()
X.shape
# Out:
# (5572, 100)

# %% [markdown]
# ### N-grams

# %%
sorted(cv.vocabulary_.items(), key=lambda item: item[1],reverse=True)
# Out:
# [('yes', np.int64(99)),
#  ('year', np.int64(98)),
#  ('yeah', np.int64(97)),
#  ('work', np.int64(96)),
#  ('win', np.int64(95)),
#  ('well', np.int64(94)),
#  ('week', np.int64(93)),
#  ('way', np.int64(92)),
#  ('wat', np.int64(91)),
#  ('want', np.int64(90)),
#  ('wan', np.int64(89)),
#  ('ur', np.int64(88)),
#  ('txt', np.int64(87)),
#  ('tomorrow', np.int64(86)),
#  ('today', np.int64(85)),
#  ('time', np.int64(84)),
#  ('think', np.int64(83)),
#  ('thing', np.int64(82)),
#  ('thats', np.int64(81)),
#  ('thanks', np.int64(80)),
#  ('text', np.int64(79)),
#  ('tell', np.int64(78)),
#  ('take', np.int64(77)),
#  ('stop', np.int64(76)),
#  ('still', np.int64(75)),
#  ('sorry', np.int64(74)),
#  ('service', np.int64(73)),
#  ('send', np.int64(72)),
#  ('see', np.int64(71)),
#  ('say', np.int64(70)),
#  ('said', np.int64(69)),
#  ('right', np.int64(68)),
#  ('reply', np.int64(67)),
#  ('really', np.int64(66)),
#  ('prize', np.int64(65)),
#  ('pls', np.int64(64)),
#  ('please', np.int64(63)),
#  ('pick', np.int64(62)),
#  ('phone', np.int64(61)),
#  ('one', np.int64(60)),
#  ('ok', np.int64(59)),
#  ('oh', np.int64(58)),
#  ('number', np.int64(57)),
#  ('night', np.int64(56)),
#  ('new', np.int64(55)),
#  ('need', np.int64(54)),
#  ('na', np.int64(53)),
#  ('much', np.int64(52)),
#  ('msg', np.int64(51)),
#  ('morning', np.int64(50)),
#  ('mobile', np.int64(49)),
#  ('miss', np.int64(48)),
#  ('min', np.int64(47)),
#  ('message', np.int64(46)),
#  ('meet', np.int64(45)),
#  ('make', np.int64(44)),
#  ('ltgt', np.int64(43)),
#  ('love', np.int64(42)),
#  ('lor', np.int64(41)),
#  ('lol', np.int64(40)),
#  ('like', np.int64(39)),
#  ('let', np.int64(38)),
#  ('later', np.int64(37)),
#  ('last', np.int64(36)),
#  ('know', np.int64(35)),
#  ('ive', np.int64(34)),
#  ('im', np.int64(33)),
#  ('ill', np.int64(32)),
#  ('hope', np.int64(31)),
#  ('home', np.int64(30)),
#  ('hi', np.int64(29)),
#  ('hey', np.int64(28)),
#  ('happy', np.int64(27)),
#  ('great', np.int64(26)),
#  ('got', np.int64(25)),
#  ('good', np.int64(24)),
#  ('going', np.int64(23)),
#  ('go', np.int64(22)),
#  ('give', np.int64(21)),
#  ('get', np.int64(20)),
#  ('friend', np.int64(19)),
#  ('free', np.int64(18)),
#  ('find', np.int64(17)),
#  ('dont', np.int64(16)),
#  ('didnt', np.int64(15)),
#  ('dear', np.int64(14)),
#  ('day', np.int64(13)),
#  ('da', np.int64(12)),
#  ('contact', np.int64(11)),
#  ('come', np.int64(10)),
#  ('co', np.int64(9)),
#  ('claim', np.int64(8)),
#  ('cash', np.int64(7)),
#  ('cant', np.int64(6)),
#  ('call', np.int64(5)),
#  ('back', np.int64(4)),
#  ('babe', np.int64(3)),
#  ('ask', np.int64(2)),
#  ('anything', np.int64(1)),
#  ('already', np.int64(0))]

# %%
#using only bigram and trigram
cv1=CountVectorizer(binary=True,max_features=100,ngram_range=(2,3))
X=cv1.fit_transform(corpus_lemmatized).toarray()

# %%
sorted(cv1.vocabulary_.items(), key=lambda item: item[1],reverse=True)
# Out:
# [('week txt', np.int64(99)),
#  ('wat time', np.int64(98)),
#  ('want go', np.int64(97)),
#  ('want come', np.int64(96)),
#  ('wan na', np.int64(95)),
#  ('valid 12hrs', np.int64(94)),
#  ('urgent mobile', np.int64(93)),
#  ('ur mob', np.int64(92)),
#  ('ur mate', np.int64(91)),
#  ('ur friend', np.int64(90)),
#  ('ur awarded', np.int64(89)),
#  ('txt stop', np.int64(88)),
#  ('txt nokia', np.int64(87)),
#  ('trying contact', np.int64(86)),
#  ('tell ur', np.int64(85)),
#  ('take care', np.int64(84)),
#  ('sorry ill call', np.int64(83)),
#  ('sorry ill', np.int64(82)),
#  ('show 800', np.int64(81)),
#  ('send stop', np.int64(80)),
#  ('send message', np.int64(79)),
#  ('selected receive', np.int64(78)),
#  ('sae tc', np.int64(77)),
#  ('reply call 08000930705', np.int64(76)),
#  ('reply call', np.int64(75)),
#  ('prize guaranteed call', np.int64(74)),
#  ('prize guaranteed', np.int64(73)),
#  ('prize claim', np.int64(72)),
#  ('private 2003 account', np.int64(71)),
#  ('private 2003', np.int64(70)),
#  ('po box', np.int64(69)),
#  ('pls send message', np.int64(68)),
#  ('pls send', np.int64(67)),
#  ('please call', np.int64(66)),
#  ('pick phone', np.int64(65)),
#  ('ok lor', np.int64(64)),
#  ('nice day', np.int64(63)),
#  ('new year', np.int64(62)),
#  ('network min', np.int64(61)),
#  ('ltgt min', np.int64(60)),
#  ('line claim', np.int64(59)),
#  ('like ltgt', np.int64(58)),
#  ('let know', np.int64(57)),
#  ('last night', np.int64(56)),
#  ('land line claim', np.int64(55)),
#  ('land line', np.int64(54)),
#  ('im home', np.int64(53)),
#  ('im gon na', np.int64(52)),
#  ('im gon', np.int64(51)),
#  ('im going', np.int64(50)),
#  ('ill call later', np.int64(49)),
#  ('ill call', np.int64(48)),
#  ('identifier code', np.int64(47)),
#  ('hope good', np.int64(46)),
#  ('happy new year', np.int64(45)),
#  ('happy new', np.int64(44)),
#  ('half price', np.int64(43)),
#  ('gud ni8', np.int64(42)),
#  ('gud mrng', np.int64(41)),
#  ('guaranteed call', np.int64(40)),
#  ('great day', np.int64(39)),
#  ('got ta', np.int64(38)),
#  ('good night', np.int64(37)),
#  ('good morning', np.int64(36)),
#  ('good afternoon', np.int64(35)),
#  ('gon na', np.int64(34)),
#  ('gift voucher', np.int64(33)),
#  ('free text', np.int64(32)),
#  ('free entry', np.int64(31)),
#  ('free call', np.int64(30)),
#  ('every week', np.int64(29)),
#  ('draw show', np.int64(28)),
#  ('double min', np.int64(27)),
#  ('dont want', np.int64(26)),
#  ('dont think', np.int64(25)),
#  ('dont miss', np.int64(24)),
#  ('dont know', np.int64(23)),
#  ('dating service', np.int64(22)),
#  ('customer service', np.int64(21)),
#  ('claim ur', np.int64(20)),
#  ('claim call', np.int64(19)),
#  ('chance win', np.int64(18)),
#  ('cant wait', np.int64(17)),
#  ('cant pick', np.int64(16)),
#  ('camera phone', np.int64(15)),
#  ('camcorder reply', np.int64(14)),
#  ('caller prize', np.int64(13)),
#  ('call mobileupd8', np.int64(12)),
#  ('call later', np.int64(11)),
#  ('call customer service', np.int64(10)),
#  ('call customer', np.int64(9)),
#  ('call 08000930705', np.int64(8)),
#  ('await collection', np.int64(7)),
#  ('attempt contact', np.int64(6)),
#  ('account statement', np.int64(5)),
#  ('2nd attempt', np.int64(4)),
#  ('2003 account statement', np.int64(3)),
#  ('2003 account', np.int64(2)),
#  ('2000 prize', np.int64(1)),
#  ('1000 cash', np.int64(0))]

# %%
cv2=CountVectorizer(binary=True,max_features=500,ngram_range=(1,3))
X=cv2.fit_transform(corpus_lemmatized).toarray()

# %%
cv2.vocabulary_
# Out:
# {'go': np.int64(164),
#  'point': np.int64(336),
#  'great': np.int64(174),
#  'world': np.int64(484),
#  'got': np.int64(173),
#  'wat': np.int64(462),
#  'ok': np.int64(305),
#  'lar': np.int64(225),
#  'wif': np.int64(474),
#  'free': np.int64(151),
#  'entry': np.int64(133),
#  'win': np.int64(476),
#  'may': np.int64(263),
#  'text': np.int64(415),
#  'receive': np.int64(355),
#  'txt': np.int64(446),
#  'apply': np.int64(34),
#  'dun': np.int64(123),
#  'say': np.int64(368),
#  'early': np.int64(125),
#  'already': np.int64(25),
#  'dont': np.int64(115),
#  'think': np.int64(422),
#  'life': np.int64(239),
#  'around': np.int64(36),
#  'though': np.int64(424),
#  'hey': np.int64(195),
#  'week': np.int64(466),
#  'word': np.int64(481),
#  'back': np.int64(46),
#  'id': np.int64(206),
#  'like': np.int64(240),
#  'fun': np.int64(157),
#  'still': np.int64(403),
#  'xxx': np.int64(489),
#  'send': np.int64(374),
#  '150': np.int64(4),
#  'even': np.int64(135),
#  'brother': np.int64(61),
#  'speak': np.int64(399),
#  'per': np.int64(319),
#  'set': np.int64(378),
#  'friend': np.int64(153),
#  'network': np.int64(290),
#  'customer': np.int64(98),
#  'selected': np.int64(373),
#  'prize': np.int64(342),
#  'claim': np.int64(82),
#  'call': np.int64(66),
#  'code': np.int64(86),
#  'valid': np.int64(451),
#  'hour': np.int64(201),
#  'mobile': np.int64(276),
#  'month': np.int64(279),
#  'latest': np.int64(229),
#  'colour': np.int64(89),
#  'camera': np.int64(71),
#  'co': np.int64(85),
#  'free call': np.int64(152),
#  'im': np.int64(210),
#  'gon': np.int64(168),
#  'na': np.int64(287),
#  'home': np.int64(198),
#  'soon': np.int64(394),
#  'want': np.int64(460),
#  'talk': np.int64(411),
#  'stuff': np.int64(406),
#  'tonight': np.int64(435),
#  'ive': np.int64(216),
#  'enough': np.int64(132),
#  'today': np.int64(430),
#  'im gon': np.int64(212),
#  'gon na': np.int64(169),
#  'im gon na': np.int64(213),
#  'chance': np.int64(76),
#  'cash': np.int64(75),
#  '100': np.int64(1),
#  'pound': np.int64(338),
#  'cost': np.int64(94),
#  '16': np.int64(7),
#  'reply': np.int64(357),
#  'chance win': np.int64(77),
#  'urgent': np.int64(449),
#  'tc': np.int64(412),
#  'right': np.int64(358),
#  'thank': np.int64(416),
#  'wont': np.int64(480),
#  'take': np.int64(409),
#  'help': np.int64(194),
#  'time': np.int64(428),
#  'date': np.int64(103),
#  'use': np.int64(450),
#  'credit': np.int64(97),
#  'next': np.int64(294),
#  'message': np.int64(268),
#  'oh': np.int64(304),
#  'watching': np.int64(464),
#  'remember': np.int64(356),
#  'name': np.int64(288),
#  'yes': np.int64(493),
#  'make': np.int64(258),
#  'fine': np.int64(145),
#  'thats': np.int64(419),
#  'way': np.int64(465),
#  'feel': np.int64(142),
#  'miss': np.int64(273),
#  'ur': np.int64(448),
#  'going': np.int64(167),
#  'try': np.int64(442),
#  'im going': np.int64(211),
#  'pay': np.int64(317),
#  'first': np.int64(148),
#  'da': np.int64(100),
#  'aft': np.int64(21),
#  'finish': np.int64(146),
#  'lunch': np.int64(254),
#  'lor': np.int64(248),
#  'ard': np.int64(35),
#  'alright': np.int64(26),
#  'meet': np.int64(266),
#  'eat': np.int64(127),
#  'really': np.int64(354),
#  'getting': np.int64(160),
#  'know': np.int64(223),
#  'lol': np.int64(244),
#  'always': np.int64(28),
#  'bus': np.int64(63),
#  'mom': np.int64(277),
#  'left': np.int64(232),
#  'dinner': np.int64(111),
#  'love': np.int64(250),
#  'amp': np.int64(29),
#  'car': np.int64(73),
#  'ill': np.int64(207),
#  'let': np.int64(236),
#  'there': np.int64(420),
#  'room': np.int64(361),
#  'let know': np.int64(237),
#  'work': np.int64(482),
#  'wait': np.int64(454),
#  'sure': np.int64(407),
#  'doesnt': np.int64(113),
#  'live': np.int64(243),
#  'yeah': np.int64(491),
#  'till': np.int64(427),
#  'tell': np.int64(413),
#  'anything': np.int64(32),
#  'thanks': np.int64(417),
#  'ringtone': np.int64(360),
#  'uk': np.int64(447),
#  'please': np.int64(328),
#  'yup': np.int64(499),
#  'look': np.int64(246),
#  'msg': np.int64(282),
#  '2nd': np.int64(12),
#  'lesson': np.int64(235),
#  'done': np.int64(114),
#  'see': np.int64(372),
#  'hello': np.int64(193),
#  'hows': np.int64(203),
#  'trying': np.int64(443),
#  'pls': np.int64(330),
#  'wanted': np.int64(461),
#  'weekend': np.int64(467),
#  'need': np.int64(289),
#  'sweet': np.int64(408),
#  'tried': np.int64(439),
#  'sm': np.int64(390),
#  'nokia': np.int64(299),
#  'delivery': np.int64(107),
#  'tomorrow': np.int64(433),
#  'please call': np.int64(329),
#  'hope': np.int64(199),
#  'man': np.int64(260),
#  'well': np.int64(469),
#  'ltgt': np.int64(252),
#  'didnt': np.int64(110),
#  'get': np.int64(159),
#  'cant': np.int64(72),
#  'could': np.int64(95),
#  'maybe': np.int64(264),
#  'ask': np.int64(37),
#  'bit': np.int64(54),
#  'dont know': np.int64(116),
#  'saw': np.int64(367),
#  'class': np.int64(83),
#  'run': np.int64(362),
#  'half': np.int64(183),
#  'second': np.int64(371),
#  'morning': np.int64(280),
#  'he': np.int64(189),
#  'place': np.int64(324),
#  'never': np.int64(291),
#  'thought': np.int64(425),
#  'since': np.int64(387),
#  'best': np.int64(50),
#  'happy': np.int64(185),
#  'sorry': np.int64(395),
#  'give': np.int64(163),
#  'new': np.int64(292),
#  'play': np.int64(326),
#  'end': np.int64(130),
#  'yesterday': np.int64(494),
#  'find': np.int64(144),
#  'year': np.int64(492),
#  'special': np.int64(400),
#  'later': np.int64(228),
#  'meeting': np.int64(267),
#  'sorry ill': np.int64(396),
#  'ill call': np.int64(208),
#  'call later': np.int64(67),
#  'sorry ill call': np.int64(397),
#  'ill call later': np.int64(209),
#  'pick': np.int64(323),
#  'pain': np.int64(315),
#  'good': np.int64(170),
#  'girl': np.int64(162),
#  'part': np.int64(316),
#  'come': np.int64(90),
#  'double': np.int64(117),
#  'check': np.int64(81),
#  'hair': np.int64(182),
#  'said': np.int64(365),
#  'nice': np.int64(295),
#  'mob': np.int64(275),
#  'awarded': np.int64(42),
#  'bonus': np.int64(55),
#  'day': np.int64(104),
#  'trip': np.int64(440),
#  '1000': np.int64(2),
#  'dis': np.int64(112),
#  'hear': np.int64(191),
#  'money': np.int64(278),
#  'finished': np.int64(147),
#  'hi': np.int64(196),
#  'babe': np.int64(44),
#  'wan': np.int64(458),
#  'something': np.int64(393),
#  'wan na': np.int64(459),
#  'waiting': np.int64(455),
#  'cool': np.int64(93),
#  'people': np.int64(318),
#  'much': np.int64(283),
#  'pa': np.int64(314),
#  'looking': np.int64(247),
#  'job': np.int64(217),
#  'ah': np.int64(23),
#  'stop': np.int64(404),
#  'real': np.int64(353),
#  'yo': np.int64(496),
#  'one': np.int64(309),
#  'came': np.int64(70),
#  'bed': np.int64(48),
#  'wen': np.int64(470),
#  'close': np.int64(84),
#  'another': np.int64(30),
#  'night': np.int64(296),
#  'late': np.int64(227),
#  'afternoon': np.int64(22),
#  'mean': np.int64(265),
#  'havent': np.int64(188),
#  'smile': np.int64(391),
#  'hurt': np.int64(205),
#  'someone': np.int64(392),
#  'service': np.int64(377),
#  'guaranteed': np.int64(175),
#  '5000': np.int64(14),
#  'customer service': np.int64(99),
#  '1000 cash': np.int64(3),
#  'buy': np.int64(65),
#  'show': np.int64(385),
#  'po': np.int64(334),
#  'box': np.int64(58),
#  'po box': np.int64(335),
#  'abt': np.int64(17),
#  'wk': np.int64(479),
#  'forgot': np.int64(150),
#  'nothing': np.int64(300),
#  'else': np.int64(129),
#  'okay': np.int64(307),
#  'price': np.int64(339),
#  'long': np.int64(245),
#  'driving': np.int64(121),
#  'test': np.int64(414),
#  'yet': np.int64(495),
#  'youre': np.int64(497),
#  'guess': np.int64(178),
#  'lot': np.int64(249),
#  'dear': np.int64(106),
#  'wish': np.int64(477),
#  'birthday': np.int64(53),
#  'making': np.int64(259),
#  'aight': np.int64(24),
#  'would': np.int64(487),
#  'address': np.int64(20),
#  'isnt': np.int64(215),
#  'old': np.int64(308),
#  'better': np.int64(51),
#  'worry': np.int64(485),
#  'busy': np.int64(64),
#  'thing': np.int64(421),
#  'contact': np.int64(92),
#  'last': np.int64(226),
#  'draw': np.int64(118),
#  '150ppm': np.int64(6),
#  'prize guaranteed': np.int64(343),
#  'guaranteed call': np.int64(176),
#  'prize guaranteed call': np.int64(344),
#  'anyway': np.int64(33),
#  'juz': np.int64(220),
#  'went': np.int64(471),
#  'holiday': np.int64(197),
#  '18': np.int64(8),
#  'must': np.int64(286),
#  'school': np.int64(370),
#  'food': np.int64(149),
#  'private': np.int64(341),
#  'account': np.int64(18),
#  '2000': np.int64(10),
#  'landline': np.int64(224),
#  'number': np.int64(301),
#  'award': np.int64(41),
#  'rate': np.int64(350),
#  'sent': np.int64(376),
#  'answer': np.int64(31),
#  'question': np.int64(348),
#  'top': np.int64(436),
#  'player': np.int64(327),
#  'join': np.int64(218),
#  'bt': np.int64(62),
#  'haf': np.int64(180),
#  'chat': np.int64(80),
#  'yr': np.int64(498),
#  'sir': np.int64(388),
#  'mail': np.int64(257),
#  'little': np.int64(242),
#  'person': np.int64(320),
#  'heart': np.int64(192),
#  'gud': np.int64(177),
#  'ya': np.int64(490),
#  'whats': np.int64(472),
#  'sexy': np.int64(379),
#  'luv': np.int64(255),
#  'thk': np.int64(423),
#  'dream': np.int64(119),
#  'without': np.int64(478),
#  'tv': np.int64(444),
#  'leaving': np.int64(231),
#  'house': np.int64(202),
#  'boy': np.int64(59),
#  'new year': np.int64(293),
#  'keep': np.int64(221),
#  'send stop': np.int64(375),
#  'order': np.int64(312),
#  'also': np.int64(27),
#  'liao': np.int64(238),
#  'coming': np.int64(91),
#  'believe': np.int64(49),
#  'til': np.int64(426),
#  'offer': np.int64(302),
#  'guy': np.int64(179),
#  'working': np.int64(483),
#  'haha': np.int64(181),
#  'minute': np.int64(272),
#  'xmas': np.int64(488),
#  'jus': np.int64(219),
#  'si': np.int64(386),
#  'stay': np.int64(402),
#  'able': np.int64(16),
#  'every': np.int64(138),
#  'hav': np.int64(187),
#  'story': np.int64(405),
#  'tmr': np.int64(429),
#  'evening': np.int64(136),
#  'ltdecimalgt': np.int64(251),
#  'dat': np.int64(102),
#  'oso': np.int64(313),
#  'big': np.int64(52),
#  'ready': np.int64(352),
#  'noe': np.int64(298),
#  'leh': np.int64(233),
#  'sound': np.int64(398),
#  'easy': np.int64(126),
#  'called': np.int64(68),
#  'important': np.int64(214),
#  'shop': np.int64(383),
#  'happen': np.int64(184),
#  'nite': np.int64(297),
#  '500': np.int64(13),
#  'collect': np.int64(87),
#  'start': np.int64(401),
#  'good morning': np.int64(171),
#  'walk': np.int64(457),
#  'wil': np.int64(475),
#  'reach': np.int64(351),
#  'told': np.int64(432),
#  'watch': np.int64(463),
#  'thanx': np.int64(418),
#  'everything': np.int64(140),
#  'asked': np.int64(38),
#  'wake': np.int64(456),
#  'missed': np.int64(274),
#  'sleep': np.int64(389),
#  'good night': np.int64(172),
#  'voucher': np.int64(453),
#  'music': np.int64(285),
#  'wid': np.int64(473),
#  'coz': np.int64(96),
#  'true': np.int64(441),
#  'care': np.int64(74),
#  'video': np.int64(452),
#  'min': np.int64(270),
#  'shopping': np.int64(384),
#  'ring': np.int64(359),
#  'hot': np.int64(200),
#  'plan': np.int64(325),
#  'charge': np.int64(79),
#  'might': np.int64(269),
#  'full': np.int64(156),
#  'baby': np.int64(45),
#  'phone': np.int64(321),
#  'plz': np.int64(333),
#  'pls send': np.int64(331),
#  'shit': np.int64(382),
#  'book': np.int64(56),
#  'friendship': np.int64(154),
#  'game': np.int64(158),
#  'tone': np.int64(434),
#  'weekly': np.int64(468),
#  'wot': np.int64(486),
#  'made': np.int64(256),
#  'dunno': np.int64(124),
#  'dude': np.int64(122),
#  'kiss': np.int64(222),
#  'problem': np.int64(346),
#  'movie': np.int64(281),
#  'line': np.int64(241),
#  'calling': np.int64(69),
#  'post': np.int64(337),
#  'two': np.int64(445),
#  'ever': np.int64(137),
#  'take care': np.int64(410),
#  'orange': np.int64(311),
#  'ltgt min': np.int64(253),
#  'quite': np.int64(349),
#  'leave': np.int64(230),
#  'huh': np.int64(204),
#  'sat': np.int64(366),
#  'office': np.int64(303),
#  'actually': np.int64(19),
#  'put': np.int64(347),
#  'god': np.int64(165),
#  'change': np.int64(78),
#  '1st': np.int64(9),
#  'drink': np.int64(120),
#  'den': np.int64(108),
#  'bring': np.int64(60),
#  '250': np.int64(11),
#  'head': np.int64(190),
#  'eve': np.int64(134),
#  '150p': np.int64(5),
#  'mind': np.int64(271),
#  'tot': np.int64(437),
#  '10': np.int64(0),
#  'detail': np.int64(109),
#  'bad': np.int64(47),
#  'princess': np.int64(340),
#  'enjoy': np.int64(131),
#  'many': np.int64(261),
#  'sae': np.int64(364),
#  'either': np.int64(128),
#  'bored': np.int64(57),
#  'shall': np.int64(380),
#  'attempt': np.int64(39),
#  '800': np.int64(15),
#  'probably': np.int64(345),
#  'pic': np.int64(322),
#  'fuck': np.int64(155),
#  'mum': np.int64(284),
#  'sch': np.int64(369),
#  'ok lor': np.int64(306),
#  'family': np.int64(141),
#  'together': np.int64(431),
#  'dad': np.int64(101),
#  'town': np.int64(438),
#  'de': np.int64(105),
#  'every week': np.int64(139),
#  'away': np.int64(43),
#  'feeling': np.int64(143),
#  'happy new': np.int64(186),
#  'goin': np.int64(166),
#  'shes': np.int64(381),
#  'mate': np.int64(262),
#  'gift': np.int64(161),
#  'await': np.int64(40),
#  'collection': np.int64(88),
#  'sad': np.int64(363),
#  'plus': np.int64(332),
#  'online': np.int64(310),
#  'lei': np.int64(234)}
